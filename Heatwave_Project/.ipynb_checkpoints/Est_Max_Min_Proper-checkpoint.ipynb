# %% [markdown]
# # ESTIMATING MAX AND MIN TEMPERATURES THE LINEAR REGRESSION WAY

# %% [markdown]
# ## Import packages

# %%
import sys
sys.path.append(r"C:\Users\jarra\Desktop\Masters\Heatwave_Project")
import pandas as pd
import PT13_Functions_For_Masters_New_Test as HW_Func
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr
import scipy
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %% [markdown]
# ## Load/Clean Data : Perth Regional Office 1967-1992
# Load the sub daily data in

# %%
#Perth Regional Office 1967 to 1992 sub daily dataset
PRO_Sub = pd.read_csv(r"E:\LIBRARY\UNIVERSITY\Masters Research\Python\Data\perthregionaloffice_subdaily_1942-1992.csv")

PRO_Sub['date'] = pd.to_datetime(PRO_Sub['date'],dayfirst = True)
PRO_Sub = PRO_Sub.set_index('date')
PRO_Sub =PRO_Sub['temp']/10 

PRO_Sub_ES  = PRO_Sub.loc['1967':'1992']
PRO_Sub_ES =PRO_Sub_ES
PRO_Sub_0 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==0]],axis =0)
PRO_Sub_3= pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==3]],axis =0)
PRO_Sub_6= pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==6]],axis =0)
PRO_Sub_9= pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==9]],axis =0)
PRO_Sub_12= pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==12]],axis =0)
PRO_Sub_15= pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==15]],axis =0)
PRO_Sub_18= pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==18]],axis =0)
PRO_Sub_21= pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==21]],axis =0)


PRO_Sub_1 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==1]],axis =0)
PRO_Sub_2 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==2]],axis =0)
PRO_Sub_4 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==4]],axis =0)


PRO_Sub_5 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==5]],axis =0)
PRO_Sub_7 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==7]],axis =0)
PRO_Sub_8 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==8]],axis =0)


PRO_Sub_10 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==10]],axis =0)
PRO_Sub_11 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==11]],axis =0)
PRO_Sub_13 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==13]],axis =0)


PRO_Sub_14 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==14]],axis =0)
PRO_Sub_16 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==16]],axis =0)
PRO_Sub_17 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==17]],axis =0)




PRO_Sub_19 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==19]],axis =0)
PRO_Sub_20 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==20]],axis =0)
PRO_Sub_22 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==22]],axis =0)
PRO_Sub_23 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==23]],axis =0)


PRO_Sub_0 = PRO_Sub_0.reset_index()

PRO_Sub_0['date'] = pd.to_datetime(PRO_Sub_0['date']).dt.date
PRO_Sub_0 = PRO_Sub_0.set_index('date')

PRO_Sub_3 = PRO_Sub_3.reset_index()
PRO_Sub_3['date'] = pd.to_datetime(PRO_Sub_3['date']).dt.date
PRO_Sub_3 = PRO_Sub_3.set_index('date')


PRO_Sub_6 = PRO_Sub_6.reset_index()
PRO_Sub_6['date'] = pd.to_datetime(PRO_Sub_6['date']).dt.date
PRO_Sub_6 = PRO_Sub_6.set_index('date')

PRO_Sub_9 = PRO_Sub_9.reset_index()
PRO_Sub_9['date'] = pd.to_datetime(PRO_Sub_9['date']).dt.date
PRO_Sub_9 = PRO_Sub_9.set_index('date')

PRO_Sub_12 = PRO_Sub_12.reset_index()
PRO_Sub_12['date'] = pd.to_datetime(PRO_Sub_12['date']).dt.date
PRO_Sub_12 = PRO_Sub_12.set_index('date')

PRO_Sub_15 = PRO_Sub_15.reset_index()
PRO_Sub_15['date'] = pd.to_datetime(PRO_Sub_15['date']).dt.date
PRO_Sub_15 = PRO_Sub_15.set_index('date')

PRO_Sub_18 = PRO_Sub_18.reset_index()
PRO_Sub_18['date'] = pd.to_datetime(PRO_Sub_18['date']).dt.date
PRO_Sub_18 = PRO_Sub_18.set_index('date')

PRO_Sub_21 = PRO_Sub_21.reset_index()
PRO_Sub_21['date'] = pd.to_datetime(PRO_Sub_21['date']).dt.date
PRO_Sub_21 = PRO_Sub_21.set_index('date')


#Now make it its own DataFrame
PRO_Sub_1 = PRO_Sub_1.reset_index()
PRO_Sub_1['date'] = pd.to_datetime(PRO_Sub_1['date']).dt.date
PRO_Sub_1 = PRO_Sub_1.set_index('date')

PRO_Sub_2 = PRO_Sub_2.reset_index()
PRO_Sub_2['date'] = pd.to_datetime(PRO_Sub_2['date']).dt.date
PRO_Sub_2 = PRO_Sub_2.set_index('date')


PRO_Sub_4 = PRO_Sub_4.reset_index()
PRO_Sub_4['date'] = pd.to_datetime(PRO_Sub_4['date']).dt.date
PRO_Sub_4 = PRO_Sub_4.set_index('date')

PRO_Sub_5 = PRO_Sub_5.reset_index()
PRO_Sub_5['date'] = pd.to_datetime(PRO_Sub_5['date']).dt.date
PRO_Sub_5 = PRO_Sub_5.set_index('date')

PRO_Sub_7 = PRO_Sub_7.reset_index()
PRO_Sub_7['date'] = pd.to_datetime(PRO_Sub_7['date']).dt.date
PRO_Sub_7 = PRO_Sub_7.set_index('date')

PRO_Sub_8 = PRO_Sub_8.reset_index()
PRO_Sub_8['date'] = pd.to_datetime(PRO_Sub_8['date']).dt.date
PRO_Sub_8 = PRO_Sub_8.set_index('date')

PRO_Sub_10 = PRO_Sub_10.reset_index()
PRO_Sub_10['date'] = pd.to_datetime(PRO_Sub_10['date']).dt.date
PRO_Sub_10 = PRO_Sub_10.set_index('date')

PRO_Sub_11 = PRO_Sub_11.reset_index()
PRO_Sub_11['date'] = pd.to_datetime(PRO_Sub_11['date']).dt.date
PRO_Sub_11 = PRO_Sub_11.set_index('date')



PRO_Sub_13 = PRO_Sub_13.reset_index()
PRO_Sub_13['date'] = pd.to_datetime(PRO_Sub_13['date']).dt.date
PRO_Sub_13 = PRO_Sub_13.set_index('date')

PRO_Sub_14 = PRO_Sub_14.reset_index()
PRO_Sub_14['date'] = pd.to_datetime(PRO_Sub_14['date']).dt.date
PRO_Sub_14 = PRO_Sub_14.set_index('date')


PRO_Sub_16 = PRO_Sub_16.reset_index()
PRO_Sub_16['date'] = pd.to_datetime(PRO_Sub_16['date']).dt.date
PRO_Sub_16 = PRO_Sub_16.set_index('date')

PRO_Sub_17 = PRO_Sub_17.reset_index()
PRO_Sub_17['date'] = pd.to_datetime(PRO_Sub_17['date']).dt.date
PRO_Sub_17 = PRO_Sub_17.set_index('date')

PRO_Sub_19 = PRO_Sub_19.reset_index()
PRO_Sub_19['date'] = pd.to_datetime(PRO_Sub_19['date']).dt.date
PRO_Sub_19 = PRO_Sub_19.set_index('date')

PRO_Sub_20 = PRO_Sub_20.reset_index()
PRO_Sub_20['date'] = pd.to_datetime(PRO_Sub_20['date']).dt.date
PRO_Sub_20 = PRO_Sub_20.set_index('date')

PRO_Sub_22 = PRO_Sub_22.reset_index()
PRO_Sub_22['date'] = pd.to_datetime(PRO_Sub_22['date']).dt.date
PRO_Sub_22 = PRO_Sub_22.set_index('date')

PRO_Sub_23 = PRO_Sub_23.reset_index()
PRO_Sub_23['date'] = pd.to_datetime(PRO_Sub_23['date']).dt.date
PRO_Sub_23 = PRO_Sub_23.set_index('date')

#Rename the columns

PRO_Sub_0 = PRO_Sub_0.rename(columns={'temp':'hour 0'})
PRO_Sub_3 = PRO_Sub_3.rename(columns={'temp':'hour 3'})
PRO_Sub_6 = PRO_Sub_6.rename(columns={'temp':'hour 6'})
PRO_Sub_9 = PRO_Sub_9.rename(columns={'temp':'hour 9'})
PRO_Sub_12 = PRO_Sub_12.rename(columns={'temp':'hour 12'})
PRO_Sub_15 = PRO_Sub_15.rename(columns={'temp':'hour 15'})
PRO_Sub_18= PRO_Sub_18.rename(columns={'temp':'hour 18'})
PRO_Sub_21 = PRO_Sub_21.rename(columns={'temp':'hour 21'})
PRO_Sub_1 = PRO_Sub_1.rename(columns={'temp':'hour 1'})
PRO_Sub_2 = PRO_Sub_2.rename(columns={'temp':'hour 2'})
PRO_Sub_4 = PRO_Sub_4.rename(columns={'temp':'hour 4'})
PRO_Sub_5 = PRO_Sub_5.rename(columns={'temp':'hour 5'})
PRO_Sub_7 = PRO_Sub_7.rename(columns={'temp':'hour 7'})
PRO_Sub_8 = PRO_Sub_8.rename(columns={'temp':'hour 8'})
PRO_Sub_10= PRO_Sub_10.rename(columns={'temp':'hour 10'})
PRO_Sub_11 = PRO_Sub_11.rename(columns={'temp':'hour 11'})
PRO_Sub_13 = PRO_Sub_13.rename(columns={'temp':'hour 13'})
PRO_Sub_14 = PRO_Sub_14.rename(columns={'temp':'hour 14'})
PRO_Sub_16 = PRO_Sub_16.rename(columns={'temp':'hour 16'})
PRO_Sub_17 = PRO_Sub_17.rename(columns={'temp':'hour 17'})
PRO_Sub_19 = PRO_Sub_19.rename(columns={'temp':'hour 19'})
PRO_Sub_20 = PRO_Sub_20.rename(columns={'temp':'hour 20'})
PRO_Sub_22= PRO_Sub_22.rename(columns={'temp':'hour 22'})
PRO_Sub_23 = PRO_Sub_23.rename(columns={'temp':'hour 23'})

#Merge the data together
#First Merge
PR01 = pd.merge(PRO_Sub_0,PRO_Sub_1, on = ['date'], how  = 'left')

PR23 = pd.merge(PRO_Sub_2,PRO_Sub_3, on = ['date'], how  = 'right')

PR45 = pd.merge(PRO_Sub_4,PRO_Sub_5, on = ['date'], how  = 'right')

PR67 = pd.merge(PRO_Sub_6,PRO_Sub_7, on = ['date'], how  = 'left')

PR89 = pd.merge(PRO_Sub_8,PRO_Sub_9, on = ['date'], how  = 'right')

PR1011 =pd.merge(PRO_Sub_10,PRO_Sub_11, on = ['date'], how  = 'right')

PR1213 =pd.merge(PRO_Sub_12,PRO_Sub_13, on = ['date'], how  = 'left')

PR1415 = pd.merge(PRO_Sub_14,PRO_Sub_15, on = ['date'], how  = 'right')

PR1617 = pd.merge(PRO_Sub_16,PRO_Sub_17, on = ['date'], how  = 'right')

PR1819 =pd.merge(PRO_Sub_18,PRO_Sub_19, on = ['date'], how  = 'left')

PR2021 =pd.merge(PRO_Sub_20,PRO_Sub_21, on = ['date'], how  = 'right')

PR2223 =pd.merge(PRO_Sub_22,PRO_Sub_23, on = ['date'], how  = 'right')

#Second Merge
PR0123 = pd.merge(PR01,PR23, on = ['date'], how  = 'left')
PR4567 = pd.merge(PR45,PR67, on = ['date'], how  = 'right')
PR891011 = pd.merge(PR89,PR1011, on = ['date'], how  = 'left')
PR12131415 = pd.merge(PR1213,PR1415, on = ['date'], how  = 'left')
PR16171819 = pd.merge(PR1617,PR1819, on = ['date'], how  = 'right')
PR20212223 = pd.merge(PR2021,PR2223, on = ['date'], how  = 'left')

#Third Merge
PR_1 = pd.merge(PR0123,PR4567, on = ['date'], how  = 'left')
PR_2 = pd.merge(PR891011,PR12131415, on = ['date'], how  = 'left')
PR_3 = pd.merge(PR16171819,PR20212223, on = ['date'], how  = 'left')

#Fourth Merge
PR_L =  pd.merge(PR_1,PR_2, on = ['date'], how  = 'left')

#Fifth Merge
PR_FULL_MATRIX =  pd.merge(PR_L,PR_3, on = ['date'], how  = 'left')

#Clean Data Up
PR_FULL_MATRIX = PR_FULL_MATRIX.reset_index()
PR_FULL_MATRIX['date'] = pd.to_datetime(PR_FULL_MATRIX['date'])
PR_FULL_MATRIX = PR_FULL_MATRIX.set_index('date')
PR_FULL_MATRIX
# Out:
#             hour 0  hour 1  hour 2  hour 3  hour 4  hour 5  hour 6  hour 7  \
# date
# 1967-01-01    18.3     NaN     NaN    17.3     NaN     NaN    17.7     NaN
# 1967-01-02    20.6     NaN     NaN    20.4     NaN     NaN    20.4     NaN
# 1967-01-03    20.9     NaN     NaN    19.7     NaN     NaN    19.9     NaN
# 1967-01-04    19.0     NaN     NaN    17.7     NaN     NaN    18.1     NaN
# 1967-01-05    17.1     NaN     NaN    16.7     NaN     NaN    17.2     NaN
# ...            ...     ...     ...     ...     ...     ...     ...     ...
# 1992-04-06    20.6     NaN     NaN    19.3     NaN     NaN    18.0     NaN
# 1992-04-07    20.9     NaN     NaN    18.8     NaN     NaN    18.4     NaN
# 1992-04-08    19.8     NaN     NaN    19.0     NaN     NaN    17.9     NaN
# 1992-04-09    19.5     NaN     NaN    17.8     NaN     NaN    15.8     NaN
# 1992-04-10    19.3     NaN     NaN    17.8     NaN     NaN    16.0     NaN
#
#             hour 8  hour 9  ...  hour 14  hour 15  hour 16  hour 17  hour 18  \
# date                        ...
# 1967-01-01     NaN    25.1  ...      NaN     28.6      NaN      NaN     26.0
# 1967-01-02     NaN    23.9  ...      NaN     26.1      NaN      NaN     23.6
# 1967-01-03     NaN    25.4  ...      NaN     24.1      NaN      NaN     22.3
# 1967-01-04     NaN    21.7  ...      NaN     24.0      NaN      NaN     18.7
# 1967-01-05     NaN    18.4  ...      NaN     20.1      NaN      NaN     19.8
# ...            ...     ...  ...      ...      ...      ...      ...      ...
# 1992-04-06     NaN    20.3  ...      NaN     27.2      NaN      NaN     25.0
# 1992-04-07     NaN    20.3  ...      NaN     20.6      NaN      NaN     21.2
# 1992-04-08     NaN    21.2  ...      NaN     25.7      NaN      NaN     24.3
# 1992-04-09     NaN    19.8  ...      NaN     25.1      NaN      NaN     22.6
# 1992-04-10     NaN    18.0  ...      NaN     24.3      NaN      NaN      NaN
#
#             hour 19  hour 20  hour 21  hour 22  hour 23
# date
# 1967-01-01      NaN      NaN     22.2      NaN      NaN
# 1967-01-02      NaN      NaN     20.5      NaN      NaN
# 1967-01-03      NaN      NaN     19.9      NaN      NaN
# 1967-01-04      NaN      NaN     18.3      NaN      NaN
# 1967-01-05      NaN      NaN     17.6      NaN      NaN
# ...             ...      ...      ...      ...      ...
# 1992-04-06      NaN      NaN     23.0      NaN      NaN
# 1992-04-07      NaN      NaN     20.2      NaN      NaN
# 1992-04-08      NaN      NaN     21.1      NaN      NaN
# 1992-04-09      NaN      NaN     20.6      NaN      NaN
# 1992-04-10      NaN      NaN      NaN      NaN      NaN
#
# [8872 rows x 24 columns]

# %%
## Perth Regional Office Daily Extreme Dataset
#Load PRO in
#BOM PERTH REGIONAL OFFICE
MaxT_PRO = pd.read_csv(r"E:\LIBRARY\UNIVERSITY\Masters Research\Python\Data\IDCJAC0010_009034_1800_Data.csv")
MinT_PRO = pd.read_csv(r"E:\LIBRARY\UNIVERSITY\Masters Research\Python\Data\IDCJAC0011_009034_1800_Data.csv")

#Clean The data
MaxT_PRO['Datetime']= pd.to_datetime(MaxT_PRO[['Year', 'Month', 'Day']])
MinT_PRO['Datetime']= pd.to_datetime(MinT_PRO[['Year', 'Month', 'Day']])

#Delete irrelevent columns
del MaxT_PRO['Product code']
del MaxT_PRO['Bureau of Meteorology station number']
del MaxT_PRO['Year']
del MaxT_PRO['Month']
del MaxT_PRO['Day']
del MaxT_PRO['Days of accumulation of maximum temperature']
del MaxT_PRO['Quality']
del MinT_PRO['Product code']
del MinT_PRO['Bureau of Meteorology station number']
del MinT_PRO['Year']
del MinT_PRO['Month']
del MinT_PRO['Day']
del MinT_PRO['Days of accumulation of minimum temperature']
del MinT_PRO['Quality']

#Change the column name to date
MaxT_PRO= MaxT_PRO.rename(columns={'Datetime':'date'})
MinT_PRO= MinT_PRO.rename(columns={'Datetime':'date'})


#Change the column names
MaxT_PRO= MaxT_PRO.rename(columns={'Maximum temperature (Degree C)':'PRO Max'})
MinT_PRO= MinT_PRO.rename(columns={'Minimum temperature (Degree C)':'PRO Min'})

#Now concat it
MaxT_PRO= MaxT_PRO.set_index('date')
MinT_PRO= MinT_PRO.set_index('date')

PRO_DE = pd.merge(left = MaxT_PRO,right  =MinT_PRO,left_index=True,right_index=True  )
PRO_DE
# Out:
#             PRO Max  PRO Min
# date
# 1897-01-01     30.6     19.4
# 1897-01-02     29.4     17.8
# 1897-01-03     27.8     18.3
# 1897-01-04     31.7     14.4
# 1897-01-05     36.7     16.1
# ...             ...      ...
# 1992-04-25     29.6     15.7
# 1992-04-26     30.0     19.5
# 1992-04-27     22.4     15.7
# 1992-04-28     22.7     15.7
# 1992-04-29     24.6     16.3
#
# [34817 rows x 2 columns]

# %%
#Combine the Max and Min with the Subdaily
Perth_Regional_Office = pd.merge(left = PR_FULL_MATRIX,right  =PRO_DE,left_index=True,right_index=True  )

#Now Every Single Available hour and max and min is ready to be used.
Perth_Regional_Office
# Out:
#             hour 0  hour 1  hour 2  hour 3  hour 4  hour 5  hour 6  hour 7  \
# date
# 1967-01-01    18.3     NaN     NaN    17.3     NaN     NaN    17.7     NaN
# 1967-01-02    20.6     NaN     NaN    20.4     NaN     NaN    20.4     NaN
# 1967-01-03    20.9     NaN     NaN    19.7     NaN     NaN    19.9     NaN
# 1967-01-04    19.0     NaN     NaN    17.7     NaN     NaN    18.1     NaN
# 1967-01-05    17.1     NaN     NaN    16.7     NaN     NaN    17.2     NaN
# ...            ...     ...     ...     ...     ...     ...     ...     ...
# 1992-04-06    20.6     NaN     NaN    19.3     NaN     NaN    18.0     NaN
# 1992-04-07    20.9     NaN     NaN    18.8     NaN     NaN    18.4     NaN
# 1992-04-08    19.8     NaN     NaN    19.0     NaN     NaN    17.9     NaN
# 1992-04-09    19.5     NaN     NaN    17.8     NaN     NaN    15.8     NaN
# 1992-04-10    19.3     NaN     NaN    17.8     NaN     NaN    16.0     NaN
#
#             hour 8  hour 9  ...  hour 16  hour 17  hour 18  hour 19  hour 20  \
# date                        ...
# 1967-01-01     NaN    25.1  ...      NaN      NaN     26.0      NaN      NaN
# 1967-01-02     NaN    23.9  ...      NaN      NaN     23.6      NaN      NaN
# 1967-01-03     NaN    25.4  ...      NaN      NaN     22.3      NaN      NaN
# 1967-01-04     NaN    21.7  ...      NaN      NaN     18.7      NaN      NaN
# 1967-01-05     NaN    18.4  ...      NaN      NaN     19.8      NaN      NaN
# ...            ...     ...  ...      ...      ...      ...      ...      ...
# 1992-04-06     NaN    20.3  ...      NaN      NaN     25.0      NaN      NaN
# 1992-04-07     NaN    20.3  ...      NaN      NaN     21.2      NaN      NaN
# 1992-04-08     NaN    21.2  ...      NaN      NaN     24.3      NaN      NaN
# 1992-04-09     NaN    19.8  ...      NaN      NaN     22.6      NaN      NaN
# 1992-04-10     NaN    18.0  ...      NaN      NaN      NaN      NaN      NaN
#
#             hour 21  hour 22  hour 23  PRO Max  PRO Min
# date
# 1967-01-01     22.2      NaN      NaN     33.1     16.4
# 1967-01-02     20.5      NaN      NaN     27.6     20.2
# 1967-01-03     19.9      NaN      NaN     28.2     18.9
# 1967-01-04     18.3      NaN      NaN     24.7     17.2
# 1967-01-05     17.6      NaN      NaN     21.4     16.1
# ...             ...      ...      ...      ...      ...
# 1992-04-06     23.0      NaN      NaN     27.5     17.0
# 1992-04-07     20.2      NaN      NaN     21.7     18.0
# 1992-04-08     21.1      NaN      NaN     25.8     17.7
# 1992-04-09     20.6      NaN      NaN     26.7     15.1
# 1992-04-10      NaN      NaN      NaN     24.8     15.4
#
# [8872 rows x 26 columns]

# %% [markdown]
# Split Data into months
#
# Now lets get it into the extended Summer Record with the extra months of the 10th and 4th in because we want the prior stuff for early Nov and Late March
#
# Lets get this into extended summer and break it up into individual hours

# %%
#Split into respective Months
PR_SEP = pd.concat([Perth_Regional_Office[Perth_Regional_Office.index.month==9],], axis = 0)
PR_OCT = pd.concat([Perth_Regional_Office[Perth_Regional_Office.index.month==10],], axis = 0)
PR_NOV = pd.concat([Perth_Regional_Office[Perth_Regional_Office.index.month==11],], axis = 0)
PR_DEC = pd.concat([Perth_Regional_Office[Perth_Regional_Office.index.month==12],], axis = 0)
PR_JAN = pd.concat([Perth_Regional_Office[Perth_Regional_Office.index.month==1],], axis = 0)
PR_FEB = pd.concat([Perth_Regional_Office[Perth_Regional_Office.index.month==2],], axis = 0)
PR_MAR = pd.concat([Perth_Regional_Office[Perth_Regional_Office.index.month==3],], axis = 0)
PR_APR = pd.concat([Perth_Regional_Office[Perth_Regional_Office.index.month==4],], axis = 0)

# %% [markdown]
# ## Load and Clean Data: Perth Gardens 1830-1875
# Now the Perth Regional Office Data is into their respective months which will make creating the regression much easier

# %%
#Now load in and fix Perth Gardens 1830-1875
Per_Gard = pd.read_csv(r"E:\LIBRARY\UNIVERSITY\Masters Research\Python\Data\swanriver_subdaily_1830-1875.csv")
Per_Gard
#Set Datetime
Per_Gard['date'] = pd.to_datetime(Per_Gard['date'],dayfirst = True)

#Can't set index yet.

# %%
from bisect import bisect_left

def take_closest(myList, myNumber):
    """
    Assumes myList is sorted. Returns closest value to myNumber.

    If two numbers are equally close, return the smallest number.
    """
    pos = bisect_left(myList, myNumber)
    if pos == 0:
        return myList[0]
    if pos == len(myList):
        return myList[-1]
    before = myList[pos - 1]
    after = myList[pos]
    if after - myNumber < myNumber - before:
        return after
    else:
        return before

# %%
#Lets start with index 250
Test_Run = Per_Gard.loc[1]
#We want to match to the hour closest to the 3s
hours = pd.Series([0,3,6,9,12,15,18,21,24])

#Extract hour
PG_hour = Test_Run['date'].hour


take_closest(hours, PG_hour)

#So this works, now we need to expand this into a for loop and make this a new dataframe to be added onto
#the historical time because it will make things easier
# Out:
# 15

# %%
closest_hour= []
#We want to match to the hour closest to the 3s
hours = pd.Series([0,3,6,9,12,15,18,21,24])

for i in range(len(Per_Gard)):
    Individual_Day = Per_Gard.loc[i]
    
    #Extract hour
    Individual_Hour = Individual_Day['date'].hour
    
    Closest_Ind_Hour = take_closest(hours, Individual_Hour)
    closest_hour.append(Closest_Ind_Hour)
    
#Add it as a series then combine to make it a dataframe
CL = pd.Series(closest_hour, name = 'closet hour')

Per_Gard = pd.merge(left = Per_Gard,right  =CL,left_index=True,right_index=True  )

# %% [markdown]
# Now we have closest hour, this means we can begin to write up the linear regression function that will help estimate the max and min temps of these closest hours in the old record.

# %% [markdown]
# ## Developing the Linear Regression Chart

# %%
#Using the Perth Regional Office
#Split into respective Months
PR_SEP = pd.concat([Perth_Regional_Office[Perth_Regional_Office.index.month==9],], axis = 0)
PR_OCT = pd.concat([Perth_Regional_Office[Perth_Regional_Office.index.month==10],], axis = 0)
PR_NOV = pd.concat([Perth_Regional_Office[Perth_Regional_Office.index.month==11],], axis = 0)
PR_DEC = pd.concat([Perth_Regional_Office[Perth_Regional_Office.index.month==12],], axis = 0)
PR_JAN = pd.concat([Perth_Regional_Office[Perth_Regional_Office.index.month==1],], axis = 0)
PR_FEB = pd.concat([Perth_Regional_Office[Perth_Regional_Office.index.month==2],], axis = 0)
PR_MAR = pd.concat([Perth_Regional_Office[Perth_Regional_Office.index.month==3],], axis = 0)
PR_APR = pd.concat([Perth_Regional_Office[Perth_Regional_Office.index.month==4],], axis = 0)

# %%
#Now this is the function that saves everything we need
#Define the Sept as a function
def linear_findings_MM_Subs(Month_Data):
    #Now develop the looping fields
    #The Month Used
    Month_U= Month_Data


    #Drop nans
    #Max is 9 to 9
    #Reset Index so the index is looped not the date

    i = ['hour 0','hour 3','hour 6','hour 9','hour 12','hour 15','hour 18','hour 21']
    j = ['PRO Max', 'PRO Min']
    
    
    #Most likely the Min will be between 12am and 9am
    #Most likely the Max wil be between 9am to 6pm


    a_storage= []
    b_storage = []
    CORR_storage = []
    fig, axs = plt.subplots(nrows = len(i), ncols = len(j), sharey = True, sharex = True,figsize = (21,20))

    #Let's begin by extracting the Hour First
    for I in range(len(i)):
        hour =  i[I]
        #Extract Sub Daily
        Sub_Daily = Month_U[hour].dropna()
    
        for J in range(len(j)):
            #Extract Extreme Temperatures
            MM = j[J]
            Daily_Ext = Month_U[MM].dropna()
        
            #Now combine them together so its the same length
        
            DS =  pd.merge(left = Sub_Daily, right  =Daily_Ext, left_index=True,right_index=True)
        
            #Plot The subplot and see if it works
            axs[I,J].scatter(DS[hour], DS[MM])  
            #axs[I,J].set_xlabel(hour)
            axs[I,J].set_ylabel(MM)
        
            #Now develop the linear regression equation
            A, B = np.polyfit(DS[hour], DS[MM], 1)
            a_storage.append(A)
            b_storage.append(B)
            #Find the correlation                  
            corr, _ = pearsonr(DS[hour], DS[MM])    
            #Plot the linear regression line on the axs
            axs[I,J].plot(DS[hour], A*DS[hour]+B,color ='black',label = '{} = {}*(Time:{})+({}), r\N{SUPERSCRIPT TWO}: {}'.format(MM,round(A, 2),hour,round(B, 2),round(np.power(corr,2), 3)))   
            #Plot the Legend
            axs[I,J].legend()
            CORR_storage.append(corr)
    #Append all the information we have found for that month into its max and min counterparts
    Coef_A = pd.Series(a_storage,name = 'A')
    Coef_B = pd.Series(b_storage,name = 'B')
    Coef_Corr = pd.Series(CORR_storage,name = 'Corr')
    Hours_Int = pd.Series([0,0,3,3,6,6,9,9,12,12,15,15,18,18,21,21],name = 'Hours')
    Imp_Values = pd.concat([Hours_Int, Coef_A,Coef_B,Coef_Corr],axis=1)
    
    
    Max_Values = pd.concat([Imp_Values.loc[0],Imp_Values.loc[2],Imp_Values.loc[4],Imp_Values.loc[6],Imp_Values.loc[8],Imp_Values.loc[10],Imp_Values.loc[12],Imp_Values.loc[14]],axis=1)
    Min_Values = pd.concat([Imp_Values.loc[1],Imp_Values.loc[3],Imp_Values.loc[5],Imp_Values.loc[7],Imp_Values.loc[9],Imp_Values.loc[11],Imp_Values.loc[13],Imp_Values.loc[15]],axis=1)
    
    
    #Return the plots and the information for Max and Min
    return(fig,Max_Values,Min_Values)

# %%
fig1, SEPT_IMP_Max, SEPT_IMP_Min = linear_findings_MM_Subs(PR_SEP)
fig2, OCT_IMP_Max, OCT_IMP_Min = linear_findings_MM_Subs(PR_OCT)
fig3, NOV_IMP_Max, NOV_IMP_Min = linear_findings_MM_Subs(PR_NOV)
fig4, DEC_IMP_Max, DEC_IMP_Min = linear_findings_MM_Subs(PR_DEC)
fig5, JAN_IMP_Max, JAN_IMP_Min = linear_findings_MM_Subs(PR_JAN)
fig6, FEB_IMP_Max, FEB_IMP_Min = linear_findings_MM_Subs(PR_FEB)
fig7, MAR_IMP_Max, MAR_IMP_Min = linear_findings_MM_Subs(PR_MAR)
fig8, APR_IMP_Max, APR_IMP_Min = linear_findings_MM_Subs(PR_APR)

# %% [markdown]
# ## Developing the code that identifies the month and the respective correlation and linear plot etc and estimating the Max and Min for each avaliable time period.
#
#
# What we have as usable information is:
#
# -SEPT_IMP_Max
#
#     a, b, corr, hour
#
# -SEPT_IMP_Min
#
#     a, b, corr, hour
#
# -Per_Gard
#
#     Closest hour,  date aka month,  index

# %% [markdown]
# Lets start with one point
#
# So first lets extract the index of ther Per Gards, test is i = 20

# %%
Test = Per_Gard.loc[20]
Test
# Out:
# date           1830-04-28 08:00:00
# temp                          21.9
# closet hour                      9
# Name: 20, dtype: object

# %% [markdown]
# Now, we want to extract the month out of this and also the closet hour

# %%
#Extract hour
Month_Extractor = Test['date'].month
Hour = Test['closet hour']
Temp = Test['temp']
print(Month_Extractor,Hour)
# Out:
# 4 9

# %% [markdown]
# Now with this information we go to the month that this information is from

# %%
#if else statement that will estimate the max and min for that day
if (Month_Extractor == 1):
    #Now find the hour data that is equal to the hour of closest hour.
    Value = np.divide(Hour,3)
    Information_Max = JAN_IMP_Max.iloc[:,int(Value)]
    Est_Max = Information_Max['A']*Test['temp'] + (Information_Max['B'])
    Correlation_Max =  Information_Max['Corr']
    
    Information_Min = JAN_IMP_Min.iloc[:,int(Value)]
    Est_Min = Information_Min['A']*Test['temp'] + (Information_Min['B'])
    Correlation_Min =  Information_Min['Corr']
    
    
elif (Month_Extractor == 2):
    #Now find the hour data that is equal to the hour of closest hour.
    Value = np.divide(Hour,3)
    Information_Max = FEB_IMP_Max.iloc[:,int(Value)]
    Est_Max = Information_Max['A']*Test['temp'] + (Information_Max['B'])
    Correlation_Max =  Information_Max['Corr']
    Information_Min = FEB_IMP_Min.iloc[:,int(Value)]
    Est_Min = Information_Min['A']*Test['temp'] + (Information_Min['B'])
    Correlation_Min =  Information_Min['Corr']
    
elif (Month_Extractor == 3):
    #Now find the hour data that is equal to the hour of closest hour.
    Value = np.divide(Hour,3)
    Information_Max = MAR_IMP_Max.iloc[:,int(Value)]
    Est_Max = Information_Max['A']*Test['temp'] + (Information_Max['B'])
    Correlation_Max =  Information_Max['Corr']
    Information_Min = MAR_IMP_Min.iloc[:,int(Value)]
    Est_Min = Information_Min['A']*Test['temp'] + (Information_Min['B'])
    Correlation_Min =  Information_Min['Corr']
    
    
elif (Month_Extractor == 4):
    #Now find the hour data that is equal to the hour of closest hour.
    Value = np.divide(Hour,3)
    Information_Max = APR_IMP_Max.iloc[:,int(Value)]
    Est_Max = Information_Max['A']*Test['temp'] + (Information_Max['B'])
    Correlation_Max =  Information_Max['Corr']
    Information_Min = APR_IMP_Min.iloc[:,int(Value)]
    Est_Min = Information_Min['A']*Test['temp'] + (Information_Min['B'])
    Correlation_Min =  Information_Min['Corr']
    
    
elif (Month_Extractor == 9):
    #Now find the hour data that is equal to the hour of closest hour.
    Value = np.divide(Hour,3)
    Information_Max = SEP_IMP_Max.iloc[:,int(Value)]
    Est_Max = Information_Max['A']*Test['temp'] + (Information_Max['B'])
    Correlation_Max =  Information_Max['Corr']
    Information_Min = SEP_IMP_Min.iloc[:,int(Value)]
    Est_Min = Information_Min['A']*Test['temp'] + (Information_Min['B'])
    Correlation_Min =  Information_Min['Corr']
    
    
elif (Month_Extractor == 10):
    #Now find the hour data that is equal to the hour of closest hour.
    Value = np.divide(Hour,3)
    Information_Max = OCT_IMP_Max.iloc[:,int(Value)]
    Est_Max = Information_Max['A']*Test['temp'] + (Information_Max['B'])
    Correlation_Max =  Information_Max['Corr']
    Information_Min = OCT_IMP_Min.iloc[:,int(Value)]
    Est_Min = Information_Min['A']*Test['temp'] + (Information_Min['B'])
    Correlation_Min =  Information_Min['Corr']
    
    
elif (Month_Extractor == 11):
    #Now find the hour data that is equal to the hour of closest hour.
    Value = np.divide(Hour,3)
    Information_Max = NOV_IMP_Max.iloc[:,int(Value)]
    Est_Max = Information_Max['A']*Test['temp'] + (Information_Max['B'])
    Correlation_Max =  Information_Max['Corr']
    Information_Min = NOV_IMP_Min.iloc[:,int(Value)]
    Est_Min = Information_Min['A']*Test['temp'] + (Information_Min['B'])
    Correlation_Min =  Information_Min['Corr']
    
    
elif (Month_Extractor == 12):
    #Now find the hour data that is equal to the hour of closest hour.
    Value = np.divide(Hour,3)
    Information_Max = DEC_IMP_Max.iloc[:,int(Value)]
    Est_Max = Information_Max['A']*Test['temp'] + (Information_Max['B'])
    Correlation_Max =  Information_Max['Corr']
    Information_Min = DEC_IMP_Min.iloc[:,int(Value)]
    Est_Min = Information_Min['A']*Test['temp'] + (Information_Min['B'])
    Correlation_Min =  Information_Min['Corr']
    
    
else:
    Est_Max = np.nan
    Est_Min = np.nan
    
    
    
    
print(Est_Max,Est_Min, Correlation_Max,Correlation_Min)
# Out:
# 28.26154352930965 17.899835805956386 0.7515279651330063 0.8744775732132725

# %% [markdown]
# Now putting it all together to print off the max, min corr for max and min for every index  now and then append it and make it one neat column

# %%
#The appending
Estimated_Max = []
Estimated_Min = []
Max_T_Correlation = []
Min_T_Correlation = []
Value_A = []
Value_B = []

#For loop to estimate max and min of the historical times
for Old_Day in range(len(Per_Gard)):
    Hist_Day = Per_Gard.loc[Old_Day]
    #Extract hour
    Month_Extractor = Hist_Day['date'].month
    Hour = Hist_Day['closet hour']
    Temp = Hist_Day['temp']
    
        #if else statement that will estimate the max and min for that day
    if (Month_Extractor == 1):
        #Now find the hour data that is equal to the hour of closest hour.
        Value = np.divide(Hour,3)
        
        #Max Estimator
        Information_Max = JAN_IMP_Max.iloc[:,int(Value)]
        Est_Max = Information_Max['A']*Temp + (Information_Max['B'])
        Correlation_Max =  Information_Max['Corr']
        #Min Estimator
        Information_Min = JAN_IMP_Min.iloc[:,int(Value)]
        Est_Min = Information_Min['A']*Temp + (Information_Min['B'])
        Correlation_Min =  Information_Min['Corr']
    
    
    elif (Month_Extractor == 2):
        #Now find the hour data that is equal to the hour of closest hour.
        Value = np.divide(Hour,3)
        #Max Estimator
        Information_Max = FEB_IMP_Max.iloc[:,int(Value)]
        Est_Max = Information_Max['A']*Temp + (Information_Max['B'])
        Correlation_Max =  Information_Max['Corr']
        #Min Estimator
        Information_Min = FEB_IMP_Min.iloc[:,int(Value)]
        Est_Min = Information_Min['A']*Temp + (Information_Min['B'])
        Correlation_Min =  Information_Min['Corr']
    
    elif (Month_Extractor == 3):
        #Now find the hour data that is equal to the hour of closest hour.
        Value = np.divide(Hour,3)
        #Max Estimator
        Information_Max = MAR_IMP_Max.iloc[:,int(Value)]
        Est_Max = Information_Max['A']*Temp + (Information_Max['B'])
        Correlation_Max =  Information_Max['Corr']
        #Min Estimator
        Information_Min = MAR_IMP_Min.iloc[:,int(Value)]
        Est_Min = Information_Min['A']*Temp + (Information_Min['B'])
        Correlation_Min =  Information_Min['Corr']
    
    
    elif (Month_Extractor == 4):
        #Now find the hour data that is equal to the hour of closest hour.
        Value = np.divide(Hour,3)
        #Max Estimator
        Information_Max = APR_IMP_Max.iloc[:,int(Value)]
        Est_Max = Information_Max['A']*Temp + (Information_Max['B'])
        Correlation_Max =  Information_Max['Corr']
        #Min Estimator
        Information_Min = APR_IMP_Min.iloc[:,int(Value)]
        Est_Min = Information_Min['A']*Temp + (Information_Min['B'])
        Correlation_Min =  Information_Min['Corr']
    
    
    elif (Month_Extractor == 9):
        #Now find the hour data that is equal to the hour of closest hour.
        Value = np.divide(Hour,3)
        #Max Estimator
        Information_Max = SEPT_IMP_Max.iloc[:,int(Value)]
        Est_Max = Information_Max['A']*Temp + (Information_Max['B'])
        Correlation_Max =  Information_Max['Corr']
        #Min Estimator
        Information_Min = SEPT_IMP_Max.iloc[:,int(Value)]
        Est_Min = Information_Min['A']*Temp + (Information_Min['B'])
        Correlation_Min =  Information_Min['Corr']
    
    
    elif (Month_Extractor == 10):
        #Now find the hour data that is equal to the hour of closest hour.
        Value = np.divide(Hour,3)
        #Max Estimator
        Information_Max = OCT_IMP_Max.iloc[:,int(Value)]
        Est_Max = Information_Max['A']*Test['temp'] + (Information_Max['B'])
        Correlation_Max =  Information_Max['Corr']
        #Min Estimator
        Information_Min = OCT_IMP_Min.iloc[:,int(Value)]
        Est_Min = Information_Min['A']*Temp + (Information_Min['B'])
        Correlation_Min =  Information_Min['Corr']
    
    
    elif (Month_Extractor == 11):
        #Now find the hour data that is equal to the hour of closest hour.
        Value = np.divide(Hour,3)
        #Max Estimator
        Information_Max = NOV_IMP_Max.iloc[:,int(Value)]
        Est_Max = Information_Max['A']*Temp + (Information_Max['B'])
        Correlation_Max =  Information_Max['Corr']
        #Min Estimator
        Information_Min = NOV_IMP_Min.iloc[:,int(Value)]
        Est_Min = Information_Min['A']*Temp + (Information_Min['B'])
        Correlation_Min =  Information_Min['Corr']
    
    
    elif (Month_Extractor == 12):
        #Now find the hour data that is equal to the hour of closest hour.
        Value = np.divide(Hour,3)
        #Max Estimator
        Information_Max = DEC_IMP_Max.iloc[:,int(Value)]
        Est_Max = Information_Max['A']*Temp + (Information_Max['B'])
        Correlation_Max =  Information_Max['Corr']
        #Min Estimator
        Information_Min = DEC_IMP_Min.iloc[:,int(Value)]
        Est_Min = Information_Min['A']*Temp + (Information_Min['B'])
        Correlation_Min =  Information_Min['Corr']
    
    
    else:
        Est_Max = np.nan
        Est_Min = np.nan
        Correlation_Max = np.nan
        Correlation_Max = np.nan
        
    Estimated_Max.append(Est_Max)
    Estimated_Min.append(Est_Min)
    Max_T_Correlation.append(Correlation_Max)
    Min_T_Correlation.append(Correlation_Min)


#Add to the historical period
Estimated_Max = pd.Series(Estimated_Max,name = 'Max Temp Estimation')
Estimated_Min = pd.Series(Estimated_Min,name = 'Min Temp Estimation')
Max_T_Correlation = pd.Series(Max_T_Correlation,name = 'Correlation Max T')
Min_T_Correlation = pd.Series(Min_T_Correlation,name = 'Correlation Min T')
Per_Gard_Estimation = pd.concat([Per_Gard, Estimated_Max,Estimated_Min,Max_T_Correlation,Min_T_Correlation],axis=1)

# %%
Per_Gard_Estimation.tail(50)
# Out:
#                      date  temp  closet hour  Max Temp Estimation  \
# 26343 1875-11-27 10:00:00  17.8            9            22.085190
# 26344 1875-11-27 13:00:00  18.9           12            20.466595
# 26345 1875-11-29 10:00:00  23.9            9            29.627481
# 26346 1875-11-29 16:00:00  23.3           15            24.858145
# 26347 1875-11-30 10:00:00  22.2            9            27.525531
# 26348 1875-12-01 10:00:00  20.6            9            25.322401
# 26349 1875-12-01 16:00:00  26.7           15            28.578308
# 26350 1875-12-02 10:00:00  25.0            9            30.767665
# 26351 1875-12-02 16:00:00  29.4           15            31.410466
# 26352 1875-12-03 10:00:00  28.3            9            34.851613
# 26353 1875-12-03 16:00:00  28.3           15            30.256624
# 26354 1875-12-04 10:00:00  21.7            9            26.683717
# 26355 1875-12-04 13:00:00  28.9           12            30.922727
# 26356 1875-12-06 10:00:00  23.9            9            29.406349
# 26357 1875-12-07 10:00:00  22.2            9            27.302497
# 26358 1875-12-07 16:00:00  28.3           15            30.256624
# 26359 1875-12-08 16:00:00  30.0           15            32.039834
# 26360 1875-12-09 10:00:00  27.8            9            34.232833
# 26361 1875-12-09 16:00:00  30.0           15            32.039834
# 26362 1875-12-10 10:00:00  26.1            9            32.128981
# 26363 1875-12-10 13:00:00  27.2           12            29.096934
# 26364 1875-12-13 10:00:00  23.9            9            29.406349
# 26365 1875-12-13 16:00:00  31.1           15            33.193676
# 26366 1875-12-14 10:00:00  23.9            9            29.406349
# 26367 1875-12-14 16:00:00  26.7           15            28.578308
# 26368 1875-12-15 10:00:00  24.4            9            30.025129
# 26369 1875-12-15 16:00:00  34.4           15            36.655202
# 26370 1875-12-16 10:00:00  25.6            9            31.510201
# 26371 1875-12-16 16:00:00  30.0           15            32.039834
# 26372 1875-12-17 10:00:00  22.8            9            28.045033
# 26373 1875-12-17 16:00:00  26.1           15            27.948940
# 26374 1875-12-18 10:00:00  26.1            9            32.128981
# 26375 1875-12-18 13:00:00  27.8           12            29.741331
# 26376 1875-12-20 10:00:00  24.4            9            30.025129
# 26377 1875-12-20 16:00:00  25.0           15            26.795098
# 26378 1875-12-21 10:00:00  26.7            9            32.871517
# 26379 1875-12-21 16:00:00  25.0           15            26.795098
# 26380 1875-12-22 10:00:00  21.1            9            25.941181
# 26381 1875-12-22 16:00:00  30.6           15            32.669202
# 26382 1875-12-23 10:00:00  25.6            9            31.510201
# 26383 1875-12-23 16:00:00  41.4           15            43.997832
# 26384 1875-12-24 10:00:00  24.4            9            30.025129
# 26385 1875-12-24 16:00:00  25.0           15            26.795098
# 26386 1875-12-28 16:00:00  36.7           15            39.067780
# 26387 1875-12-29 10:00:00  24.4            9            30.025129
# 26388 1875-12-29 16:00:00  33.9           15            36.130728
# 26389 1875-12-30 10:00:00  25.6            9            31.510201
# 26390 1875-12-30 16:00:00  31.1           15            33.193676
# 26391 1875-12-31 10:00:00  25.0            9            30.767665
# 26392 1875-12-31 16:00:00  25.6           15            27.424466
#
#        Min Temp Estimation  Correlation Max T  Correlation Min T
# 26343            13.331771           0.848844           0.774297
# 26344            13.225138           0.967924           0.600293
# 26345            17.544335           0.848844           0.774297
# 26346            14.895564           0.961320           0.532410
# 26347            16.370342           0.848844           0.774297
# 26348            15.809965           0.833110           0.797813
# 26349            17.418471           0.950558           0.536299
# 26350            18.864393           0.833110           0.797813
# 26351            18.355275           0.950558           0.536299
# 26352            21.155213           0.833110           0.797813
# 26353            17.973614           0.950558           0.536299
# 26354            16.573572           0.833110           0.797813
# 26355            18.299227           0.964685           0.596785
# 26356            18.100786           0.833110           0.797813
# 26357            16.920666           0.833110           0.797813
# 26358            17.973614           0.950558           0.536299
# 26359            18.563453           0.950558           0.536299
# 26360            20.808119           0.833110           0.797813
# 26361            18.563453           0.950558           0.536299
# 26362            19.628000           0.833110           0.797813
# 26363            17.637031           0.964685           0.596785
# 26364            18.100786           0.833110           0.797813
# 26365            18.945114           0.950558           0.536299
# 26366            18.100786           0.833110           0.797813
# 26367            17.418471           0.950558           0.536299
# 26368            18.447880           0.833110           0.797813
# 26369            20.090095           0.950558           0.536299
# 26370            19.280906           0.833110           0.797813
# 26371            18.563453           0.950558           0.536299
# 26372            17.337179           0.833110           0.797813
# 26373            17.210293           0.950558           0.536299
# 26374            19.628000           0.833110           0.797813
# 26375            17.870748           0.964685           0.596785
# 26376            18.447880           0.833110           0.797813
# 26377            16.828632           0.950558           0.536299
# 26378            20.044512           0.833110           0.797813
# 26379            16.828632           0.950558           0.536299
# 26380            16.157059           0.833110           0.797813
# 26381            18.771631           0.950558           0.536299
# 26382            19.280906           0.833110           0.797813
# 26383            22.518844           0.950558           0.536299
# 26384            18.447880           0.833110           0.797813
# 26385            16.828632           0.950558           0.536299
# 26386            20.888113           0.950558           0.536299
# 26387            18.447880           0.833110           0.797813
# 26388            19.916613           0.950558           0.536299
# 26389            19.280906           0.833110           0.797813
# 26390            18.945114           0.950558           0.536299
# 26391            18.864393           0.833110           0.797813
# 26392            17.036811           0.950558           0.536299

# %% [markdown]
# What we see above is that for the most part the temperatures estimate the max and min well, however there are some worries. For example if the temp observed at 3pm is higher then the temp at 12pm where the correlation at 12pm is higher, what do we take.
#
# This is where I believe I take a series of checks
# 1. Check if the day has one or more observation
# 2. No: Go to Step 7.
# 3. Yes: Go to Step 4.
# 4. Are any of the estimations below any of the observed Temperatures: Go to step 6.
# 5. Yes: Take the estimations that are above the observed
# 6. If these observations are above check the correlation and choose the highest correlation
# 7. Use this as the estimated max and min temp for that day
# 8. Fill Missing Dates as NaNs
#
#
# Now to choose the highest correlated value if there is observations on 2 or more days.

# %% [markdown]
# ## This is to get the uniform distrubition for each of the months.
#
# So we have all the new data from each of the months
#
# Now we want to dropnas from either column to make sure we have a clean dataset. Hence this will speed the other functions above up to.

# %%
#df.dropna(subset=['name', 'toy'])



#Lets select the hour 3 and the max for Dec as the test
PR_DEC_3 = PR_DEC[['hour 3', 'PRO Max']]
#Drop the Nans
PR_DEC_3 = PR_DEC_3.dropna(subset=['hour 3', 'PRO Max'])
#Reset Index

#Now create the random sample of 300 values
#Now we only want the information from this random samples as the information we will take to the next phase in identifying 
#historical heatwaves.
sampled = PR_DEC_3.sample(n=600,replace=True)

#From this we know 1.
#There is no need to do reset index
#2.
#We have 300 values for that hour which is useful
#3.
#We have dropna all the missing values needed but I have to work out how to implement this part of the code into that function

# %%
#Sample the uniform distribution
#s = np.random.uniform(0,681,600).astype(int)

#plt.hist(s, bins=np.arange(0, 681)

# %%
PR_DEC_3
# Out:
#             hour 3  PRO Max
# date
# 1967-12-01    16.2     31.7
# 1967-12-02    20.2     35.7
# 1967-12-03    24.4     35.3
# 1967-12-04    22.2     35.4
# 1967-12-05    26.1     37.1
# ...            ...      ...
# 1990-12-27    15.0     24.1
# 1990-12-28    16.2     27.4
# 1990-12-29    19.9     28.4
# 1990-12-30    17.9     25.3
# 1990-12-31    16.2     24.9
#
# [682 rows x 2 columns]

# %%
sampled = PR_DEC_3.sample(n=300,replace=True)
sampled
# Out:
#             hour 3  PRO Max
# date
# 1984-12-01    15.3     22.5
# 1987-12-07    18.5     24.9
# 1973-12-27    15.9     24.0
# 1985-12-01    18.1     22.6
# 1988-12-31    22.1     32.2
# ...            ...      ...
# 1969-12-11    15.7     23.9
# 1981-12-07    16.2     29.8
# 1980-12-20    16.7     21.7
# 1973-12-07    19.2     40.7
# 1980-12-04    16.8     34.6
#
# [300 rows x 2 columns]

# %%
#Need to reset the index, delete the date colomn and then add it to a larger array with the name of the colomn being run x

# %% [markdown]
# ## Implementation of the random uniform sampling into linear_findings_MM_Subs function Bootstrapping
#
# The function will have to be adjusted as when I use a for loop 1000 times it will have to uniformly recreate these values again and randomise which days are taken.

# %%
#Lets start with the for loop first.
i = 0 
x = 1000
for runs in range(1,x+1):
    i = i+1
    
i

#This is 1000 runs now move onto the next part adding the random sample into it
# Out:
# 1000

# %%
i = 0 
x = 1000
for runs in range(1,x+1):
    #This is the single run within the loop with the random choice. Eventually I will have to do these for every single month>
    sampled = PR_DEC_3.sample(n=300,replace=True)
    i = i+1

#Move onto naming each run and concatanating

# %%
i = 0 
x = 1000

RUNS = []
#Single initial run
#This is the single run within the loop with the random choice. Eventually I will have to do these for every single month>
individual_sampled_run_DEC_i=PR_DEC_3.sample(n=300,replace=True)
#delete date column
individual_sampled_run_DEC_i = individual_sampled_run_DEC_i.reset_index()
del individual_sampled_run_DEC_i['date']
 
#Change column names
individual_sampled_run_DEC_i= individual_sampled_run_DEC_i.rename(columns={'hour 3':'hour 3 run 1'})
individual_sampled_run_DEC_i= individual_sampled_run_DEC_i.rename(columns={'PRO Max':'PRO Max run 1'})
 
#Concate with RUNS
RUNS = individual_sampled_run_DEC_i

for rns in range(2,x+1):
    #This is the single run within the loop with the random choice. Eventually I will have to do these for every single month>
    individual_sampled_run_DEC = PR_DEC_3.sample(n=300,replace=True)
    #delete date column
    individual_sampled_run_DEC = individual_sampled_run_DEC.reset_index()
    del individual_sampled_run_DEC['date']
    
    #Change column names
    individual_sampled_run_DEC= individual_sampled_run_DEC.rename(columns={'hour 3':'hour 3 run {}'.format(rns)})
    individual_sampled_run_DEC= individual_sampled_run_DEC.rename(columns={'PRO Max':'PRO Max run {}'.format(rns)})
    
    #Concate with RUNS
    RUNS = pd.concat([RUNS, individual_sampled_run_DEC],axis=1)

#Bootstrapping Complete, Now to put this baby together and complete this entire thing once and for all.

# %% [markdown]
# # Choosing a value to date for each indiivudal day
# So we havent fully completed the estimation part, now we have to develope a series of if else statements in order to extract the best possible temperature estimation from what we have.
# So lets begin by retrieving everything we already have for this

# %%
Per_Gard_Estimation.tail(50)
# Out:
#                      date  temp  closet hour  Max Temp Estimation  \
# 26343 1875-11-27 10:00:00  17.8            9            22.085190
# 26344 1875-11-27 13:00:00  18.9           12            20.466595
# 26345 1875-11-29 10:00:00  23.9            9            29.627481
# 26346 1875-11-29 16:00:00  23.3           15            24.858145
# 26347 1875-11-30 10:00:00  22.2            9            27.525531
# 26348 1875-12-01 10:00:00  20.6            9            25.322401
# 26349 1875-12-01 16:00:00  26.7           15            28.578308
# 26350 1875-12-02 10:00:00  25.0            9            30.767665
# 26351 1875-12-02 16:00:00  29.4           15            31.410466
# 26352 1875-12-03 10:00:00  28.3            9            34.851613
# 26353 1875-12-03 16:00:00  28.3           15            30.256624
# 26354 1875-12-04 10:00:00  21.7            9            26.683717
# 26355 1875-12-04 13:00:00  28.9           12            30.922727
# 26356 1875-12-06 10:00:00  23.9            9            29.406349
# 26357 1875-12-07 10:00:00  22.2            9            27.302497
# 26358 1875-12-07 16:00:00  28.3           15            30.256624
# 26359 1875-12-08 16:00:00  30.0           15            32.039834
# 26360 1875-12-09 10:00:00  27.8            9            34.232833
# 26361 1875-12-09 16:00:00  30.0           15            32.039834
# 26362 1875-12-10 10:00:00  26.1            9            32.128981
# 26363 1875-12-10 13:00:00  27.2           12            29.096934
# 26364 1875-12-13 10:00:00  23.9            9            29.406349
# 26365 1875-12-13 16:00:00  31.1           15            33.193676
# 26366 1875-12-14 10:00:00  23.9            9            29.406349
# 26367 1875-12-14 16:00:00  26.7           15            28.578308
# 26368 1875-12-15 10:00:00  24.4            9            30.025129
# 26369 1875-12-15 16:00:00  34.4           15            36.655202
# 26370 1875-12-16 10:00:00  25.6            9            31.510201
# 26371 1875-12-16 16:00:00  30.0           15            32.039834
# 26372 1875-12-17 10:00:00  22.8            9            28.045033
# 26373 1875-12-17 16:00:00  26.1           15            27.948940
# 26374 1875-12-18 10:00:00  26.1            9            32.128981
# 26375 1875-12-18 13:00:00  27.8           12            29.741331
# 26376 1875-12-20 10:00:00  24.4            9            30.025129
# 26377 1875-12-20 16:00:00  25.0           15            26.795098
# 26378 1875-12-21 10:00:00  26.7            9            32.871517
# 26379 1875-12-21 16:00:00  25.0           15            26.795098
# 26380 1875-12-22 10:00:00  21.1            9            25.941181
# 26381 1875-12-22 16:00:00  30.6           15            32.669202
# 26382 1875-12-23 10:00:00  25.6            9            31.510201
# 26383 1875-12-23 16:00:00  41.4           15            43.997832
# 26384 1875-12-24 10:00:00  24.4            9            30.025129
# 26385 1875-12-24 16:00:00  25.0           15            26.795098
# 26386 1875-12-28 16:00:00  36.7           15            39.067780
# 26387 1875-12-29 10:00:00  24.4            9            30.025129
# 26388 1875-12-29 16:00:00  33.9           15            36.130728
# 26389 1875-12-30 10:00:00  25.6            9            31.510201
# 26390 1875-12-30 16:00:00  31.1           15            33.193676
# 26391 1875-12-31 10:00:00  25.0            9            30.767665
# 26392 1875-12-31 16:00:00  25.6           15            27.424466
#
#        Min Temp Estimation  Correlation Max T  Correlation Min T
# 26343            13.331771           0.848844           0.774297
# 26344            13.225138           0.967924           0.600293
# 26345            17.544335           0.848844           0.774297
# 26346            14.895564           0.961320           0.532410
# 26347            16.370342           0.848844           0.774297
# 26348            15.809965           0.833110           0.797813
# 26349            17.418471           0.950558           0.536299
# 26350            18.864393           0.833110           0.797813
# 26351            18.355275           0.950558           0.536299
# 26352            21.155213           0.833110           0.797813
# 26353            17.973614           0.950558           0.536299
# 26354            16.573572           0.833110           0.797813
# 26355            18.299227           0.964685           0.596785
# 26356            18.100786           0.833110           0.797813
# 26357            16.920666           0.833110           0.797813
# 26358            17.973614           0.950558           0.536299
# 26359            18.563453           0.950558           0.536299
# 26360            20.808119           0.833110           0.797813
# 26361            18.563453           0.950558           0.536299
# 26362            19.628000           0.833110           0.797813
# 26363            17.637031           0.964685           0.596785
# 26364            18.100786           0.833110           0.797813
# 26365            18.945114           0.950558           0.536299
# 26366            18.100786           0.833110           0.797813
# 26367            17.418471           0.950558           0.536299
# 26368            18.447880           0.833110           0.797813
# 26369            20.090095           0.950558           0.536299
# 26370            19.280906           0.833110           0.797813
# 26371            18.563453           0.950558           0.536299
# 26372            17.337179           0.833110           0.797813
# 26373            17.210293           0.950558           0.536299
# 26374            19.628000           0.833110           0.797813
# 26375            17.870748           0.964685           0.596785
# 26376            18.447880           0.833110           0.797813
# 26377            16.828632           0.950558           0.536299
# 26378            20.044512           0.833110           0.797813
# 26379            16.828632           0.950558           0.536299
# 26380            16.157059           0.833110           0.797813
# 26381            18.771631           0.950558           0.536299
# 26382            19.280906           0.833110           0.797813
# 26383            22.518844           0.950558           0.536299
# 26384            18.447880           0.833110           0.797813
# 26385            16.828632           0.950558           0.536299
# 26386            20.888113           0.950558           0.536299
# 26387            18.447880           0.833110           0.797813
# 26388            19.916613           0.950558           0.536299
# 26389            19.280906           0.833110           0.797813
# 26390            18.945114           0.950558           0.536299
# 26391            18.864393           0.833110           0.797813
# 26392            17.036811           0.950558           0.536299

# %%
#What we want out of this is the dates, and the MaxMinCorrs
#Lets set index to date firstly
#Per_Gard_Estimation_Date = Per_Gard_Estimation['date']
#Per_Gard_Estimation = Per_Gard_Estimation.reset_index()

# %%
# Remove the duplicates out of the day it will make it easier for the for loop trust.

#Get the individual columns for the dates
Per_Gard_Estimation['Day'] = Per_Gard_Estimation['date'].dt.day
Per_Gard_Estimation['Month'] = Per_Gard_Estimation['date'].dt.month
Per_Gard_Estimation['Year'] = Per_Gard_Estimation['date'].dt.year
Per_Gard_Estimation_Date = Per_Gard_Estimation[['date','Year','Month','Day']]

#Combine together as it removes hourly out of the datetime
Per_Gard_Estimation_Date['Undup Dates']=pd.to_datetime(Per_Gard_Estimation_Date[['Year','Month','Day']])
Per_Gard_Estimation_Date = Per_Gard_Estimation_Date.drop_duplicates(subset=['Undup Dates'])

#Delete all other column remove dups reset index for looping, keep the undup dates and sub cats as well.
Per_Gard_Estimation_Date = Per_Gard_Estimation_Date.drop_duplicates(subset=['Undup Dates'])
del Per_Gard_Estimation_Date['date']

Per_Gard_Estimation_Date = Per_Gard_Estimation_Date.reset_index(drop = True)


#The dataclean up is ready nn
# Out:
# C:\Users\jarra\AppData\Local\Temp\ipykernel_20476\1255584891.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Per_Gard_Estimation_Date['Undup Dates']=pd.to_datetime(Per_Gard_Estimation_Date[['Year','Month','Day']])

# %%
Per_Gard_Estimation = Per_Gard_Estimation.set_index('date')

# %%
# Remove the duplicates out of the day it will make it easier for the for loop trust.

#Get the individual columns for the dates
Per_Gard_Estimation['Day'] = Per_Gard_Estimation['date'].dt.day
Per_Gard_Estimation['Month'] = Per_Gard_Estimation['date'].dt.month
Per_Gard_Estimation['Year'] = Per_Gard_Estimation['date'].dt.year
Per_Gard_Estimation_Date = Per_Gard_Estimation[['date','Year','Month','Day']]

#Combine together as it removes hourly out of the datetime
Per_Gard_Estimation_Date['Undup Dates']=pd.to_datetime(Per_Gard_Estimation_Date[['Year','Month','Day']])
Per_Gard_Estimation_Date = Per_Gard_Estimation_Date.drop_duplicates(subset=['Undup Dates'])

#Delete all other column remove dups reset index for looping, keep the undup dates and sub cats as well.
Per_Gard_Estimation_Date = Per_Gard_Estimation_Date.drop_duplicates(subset=['Undup Dates'])
del Per_Gard_Estimation_Date['date']

Per_Gard_Estimation_Date = Per_Gard_Estimation_Date.reset_index(drop = True)


#The dataclean up is ready nn
Per_Gard_Estimation = Per_Gard_Estimation.set_index('date')
#Now we have to go through each individual day, check whether there is two or more values. So this is the first check
for i in range(len(Per_Gard_Estimation_Date)):
    #Get the individual date
    located_date = Per_Gard_Estimation.loc['{}-{}-{}'.format(Per_Gard_Estimation_Date['Year'][i],Per_Gard_Estimation_Date['Month'][i],Per_Gard_Estimation_Date['Day'][i])]
    #From here 
located_date = located_date.reset_index()
located_date

# %%
located_date = located_date.reset_index()
located_date
# Out:
#                  date  temp  closet hour  Max Temp Estimation  \
# 0 1875-12-31 10:00:00  25.0            9            30.767665
# 1 1875-12-31 16:00:00  25.6           15            27.424466
#
#    Min Temp Estimation  Correlation Max T  Correlation Min T  Day  Month  Year
# 0            18.864393           0.833110           0.797813   31     12  1875
# 1            17.036811           0.950558           0.536299   31     12  1875

# %% [markdown]
# Singular_Dates = []
# Predicted_Max = []
# Predicted_Min = []
# Corresonding_Corr_Mx =[]
# Corresonding_Corr_Mn = []
#
#
# #The first statement is the main one
# if (len(located_date) == 1):
#     Estimated_Max = located_date['Max Temp Estimation']
#     Estimated_Min = located_date['Min Temp Estimation']
#     Correlation_Max = located_date['Correlation Max T']
#     Correlation_Min = located_date['Correlation Min T']
# #If there is two or more subdaily recordings
# #We choose the highest correlation first
# elif (len(located_date) == 2):
#     #MAX
#     #Get the maxT and highest corresponding max
#     Max_Corr_Max = located_date.loc[located_date['Correlation Max T'] == located_date['Correlation Max T'].max()]
#     Max_temp_Obs_Max = located_date.loc[located_date['temp'] == located_date['temp'].max()]
#
#     if (Max_temp_Obs_Max['temp'] > Max_Corr_Max['Max Temp Estimation']):
#         Estimated_Max = Max_temp_Obs_Max['Max Temp Estimation']
#         Correlation_Max = Max_temp_Obs_Max['Correlation Max T']
#     else:
#         Estimated_Max = Max_Corr_Max['Max Temp Estimation']
#         Correlation_Max = Max_Corr_Max['Correlation Max T']
#
#     #MIN
#     #Get the minT and highest corresponding max
#     Min_Corr_Max = located_date.loc[located_date['Correlation Min T'] == located_date['Correlation Min T'].max()]
#     Min_temp_Obs_Max = located_date.loc[located_date['temp'] == located_date['temp'].min()]
#
#     if (Min_temp_Obs_Max['temp'] < Min_Corr_Max['Min Temp Estimation']):
#         Estimated_Min = Min_temp_Obs_Max['Max Temp Estimation']
#         Correlation_Min = Min_temp_Obs_Max['Correlation Max T']
#     else:
#         Estimated_Min = Min_Corr_Max['Max Temp Estimation']
#         Correlation_Min = Min_Corr_Max['Correlation Max T']
#
# else:
#     #Max
#     #Criteria: Does the estimated T of the highest Corr be greater then any obs
#     #The index with the largest MAX CORR
#     Max_Corr_Max = located_date.loc[located_date['Correlation Max T'] == located_date['Correlation Max T'].max()]
#     #The index with the largest Observed Temperature
#     Max_temp_Obs_Max = located_date.loc[located_date['Max Temp Estimation'] == located_date['Max Temp Estimation'].max()]
#     if (Max_temp_Obs_Max['temp'] > Max_Corr_Max['Max Temp Estimation']):
#         #This needs a check on the correlation and estimation with the observed value
#         Max_Est_Max = located_date.loc[located_date['Max Temp Estimation'] == located_date['Max Temp Estimation'].max()]
#         if (Max_temp_Obs_Max['Max Temp Estimation'] == Max_Est_Max['Max Temp Estimation']):
#             Estimated_Max = Max_temp_Obs_Max['Max Temp Estimation']
#             Correlation_Max = Max_temp_Obs_Max['Correlation Max T']
#             #Now to check correlation is this is not true
#         else:
#             if (Max_temp_Obs_Max['Correlation Max T'] >= Max_Est_Max['Correlation Max T']):
#                 Estimated_Max = Max_temp_Obs_Max['Max Temp Estimation']
#                 Correlation_Max = Max_temp_Obs_Max['Correlation Max T']
#             else:
#                 Estimated_Max = Max_Est_Max['Max Temp Estimation']
#                 Correlation_Max = Max_Est_Max['Correlation Max T']
#
#     else:
#         Estimated_Max = Max_Corr_Max['Max Temp Estimation']
#         Correlation_Max = Max_Corr_Max['Correlation Max T']
#
#     #Min
#     #Criteria: Does the estimated T of the highest Corr be greater then any obs
#     #The index with the largest MAX CORR
#     Min_Corr_Max = located_date.loc[located_date['Correlation Min T'] == located_date['Correlation Min T'].max()]
#     #The index with the largest Observed Temperature
#     Min_temp_Obs_Min = located_date.loc[located_date['temp'] == located_date['temp'].min()]
#     if (Min_temp_Obs_Max['temp'] > Min_Corr_Max['Min Temp Estimation']):
#         #This needs a check on the correlation and estimation with the observed value
#         Min_Est_Max = located_date.loc[located_date['Min Temp Estimation'] == located_date['Min Temp Estimation'].minb()]
#         if (Min_temp_Obs_Max['Min Temp Estimation'] == Min_Est_Max['Min Temp Estimation']):
#             Estimated_Min = Min_temp_Obs_Max['Min Temp Estimation']
#             Correlation_Min = Min_temp_Obs_Max['Correlation Min T']
#             #Now to check correlation is this is not true
#         else:
#             if (Min_temp_Obs_Max['Correlation Min T'] >= Min_Est_Max['Correlation Min T']):
#                 Estimated_Min = Min_temp_Obs_Max['Min Temp Estimation']
#                 Correlation_Min = Min_temp_Obs_Max['Correlation Min T']
#             else:
#                 Estimated_Min = Min_Est_Min['Min Temp Estimation']
#                 Correlation_Min = Min_Est_Max['Correlation Min T']
#
#     else:
#         Estimated_Min = Min_Corr_Max['Min Temp Estimation']
#         Correlation_Min = Min_Corr_Max['Correlation Min T']
#
#
#
# print(located_date)
# print(Estimated_Max)
# print(Estimated_Min)
# print(Correlation_Max)
# print(Correlation_Min)
#
#
#
#
#
# #Singular_Dates.append(located_date)
# #Predicted_Max.append(Estimated_Max)
# #Predicted_Min.append(Estimated_Min)
# #Corresonding_Corr_Mx.append(Correlation_Max)
# #Corresonding_Corr_Mn.append(Correlation_Min)

# %% [markdown]
# Max_temp_Obs_Max['Max Temp Estimation'].loc[1]

# %% [markdown]
# Max_Corr_Max['Max Temp Estimation'].loc[1]

# %% [markdown]
# Max_temp_Obs_Max

# %%
#So the above is the rough sketch of the code, now lets go one by one through it with a 1 2 and 3 len scenario
length_1 = Per_Gard_Estimation.loc['1875-12-06']
length_2 = Per_Gard_Estimation.loc['1830-04-16']
length_3 = Per_Gard_Estimation.loc['1830-04-29']

# %%
#My Code should expect these to pop out
length_1 =length_1.reset_index()
#From the code we expect Max Est: 29.4, Min Est: 18.1, Corr Max: 0.83, Corr Min: 0.80 #This workds
length_2 =  length_2.reset_index()
#From the code we expect Max Est: 27.0, Min Est: 15.0, Corr Max: 0.95, Corr Min: 0.58
length_3 =length_3.reset_index()
#From the code we expect Max Est: 30.1, Min Est: 18.2, Corr Max: 0.95, Corr Min: 0.87
length_3
# Out:
#                  date  temp  closet hour  Max Temp Estimation  \
# 0 1830-04-29 09:00:00  22.2            9            28.558600
# 1 1830-04-29 12:00:00  28.1           12            30.127801
# 2 1830-04-29 15:00:00  28.1           15            29.239916
#
#    Min Temp Estimation  Correlation Max T  Correlation Min T  Day  Month  Year
# 0            18.164611           0.751528           0.874478   29      4  1830
# 1            17.392226           0.952712           0.579649   29      4  1830
# 2            16.616311           0.946385           0.469305   29      4  1830

# %%
#data = length_1 
data = length_2
#data = length_3
i = 'Fo'


#Single Case: Most simple
if (len(data) == 1):
    #This finds the values required for a length of 1 data
    Estimated_Max = data['Max Temp Estimation'].loc[0]
    Estimated_Min = data['Min Temp Estimation'].loc[0]
    Correlation_Max = data['Correlation Max T'].loc[0]
    Correlation_Min = data['Correlation Min T'].loc[0]


elif (len(data) == 2):
    #--------- MAX ------------#
    #Doing something more complicated
    #First lets find the max of the correlation for the max and min
    
    #nOW FOR TWO INDICES
    #First we choose the highest correlation as the initial condition
    Mx_o_Mx_Corr = data.loc[data['Correlation Max T'] == data['Correlation Max T'].max()]
    Mx_o_Mx_Corr = Mx_o_Mx_Corr.reset_index(drop = True)
    
    #Now we want to compare this Max temp Est to the max observed twmp of that day
    Mx_o_Mx_Obs_Temp = data.loc[data['temp'] == data['temp'].max()]
    Mx_o_Mx_Obs_Temp = Mx_o_Mx_Obs_Temp.reset_index(drop = True)
    
    #Check if Est is greater or equal to the Obs, this is to ensure that the highest correlation is kept
    if (Mx_o_Mx_Corr['Max Temp Estimation'].loc[0] >= Mx_o_Mx_Obs_Temp['temp'].loc[0]):
        Estimated_Max = Mx_o_Mx_Corr['Max Temp Estimation'].loc[0]
        Correlation_Max = Mx_o_Mx_Corr['Correlation Max T'].loc[0]
    else:
        Estimated_Max = Mx_o_Mx_Obs_Temp['Max Temp Estimation'].loc[0]
        Correlation_Max = Mx_o_Mx_Obs_Temp['Correlation Max T'].loc[0]
        
     #--------- MIN ------------#
    #Doing something more complicated
    #First lets find the max of the correlation for the max and min
    
    #nOW FOR TWO INDICES
    #First we choose the highest correlation as the initial condition
    Mx_o_Mn_Corr = data.loc[data['Correlation Min T'] == data['Correlation Min T'].max()]
    Mx_o_Mn_Corr = Mx_o_Mn_Corr.reset_index(drop = True)
    
    #Now we want to compare this Max temp Est to the max observed twmp of that day
    Mn_o_Mn_Obs_Temp = data.loc[data['temp'] == data['temp'].min()]
    Mn_o_Mn_Obs_Temp = Mn_o_Mn_Obs_Temp.reset_index(drop = True)
    
    #Check if Est is greater or equal to the Obs, this is to ensure that the highest correlation is kept
    if (Mx_o_Mn_Corr['Min Temp Estimation'].loc[0] <= Mn_o_Mn_Obs_Temp['temp'].loc[0]):
        Estimated_Min = Mx_o_Mn_Corr['Min Temp Estimation'].loc[0]
        Correlation_Min = Mx_o_Mn_Corr['Correlation Min T'].loc[0]
    else:
        Estimated_Min = Mn_o_Mn_Obs_Temp['Min Temp Estimation'].loc[0]
        Correlation_Min = Mn_o_Mn_Obs_Temp['Correlation Min T'].loc[0]
    
else:
    #Doing something more complicated
    
    #------------------MAX-------------#
    #The first check is the highest correlation
    
    
    #First we choose the highest correlation as the initial condition
    Mx_o_Mx_Corr = data.loc[data['Correlation Max T'] == data['Correlation Max T'].max()]
    Mx_o_Mx_Corr = Mx_o_Mx_Corr.reset_index(drop = True)
    
    #Now we want to compare this Max temp Est to the max observed twmp of that day
    Mx_o_Mx_Obs_Temp = data.loc[data['temp'] == data['temp'].max()]
    Mx_o_Mx_Obs_Temp = Mx_o_Mx_Obs_Temp.reset_index(drop = True)
    
    #If proves that the highest correlation est is the highest value above any of the other obs temps
    #We can keep it if not
    if (Mx_o_Mx_Corr['Max Temp Estimation'].loc[0] >= Mx_o_Mx_Obs_Temp['temp'].loc[0]):
    
        Estimated_Max = Mx_o_Mx_Corr['Max Temp Estimation'].loc[0]
        Correlation_Max = Mx_o_Mx_Corr['Correlation Max T'].loc[0]
        
        
    else:
        #Now to see if the Est of the observed is the biggest estimation
        Mx_o_Mx_Est = data.loc[data['Max Temp Estimation'] == data['Max Temp Estimation'].max()]
        Mx_o_Mx_Est = Mx_o_Mx_Corr.reset_index(drop = True)
    
        #if it is keep this value as we know the max is the greatest that day
        if (Mx_o_Mx_Est['Max Temp Estimation'].loc[0] <= Mx_o_Mx_Obs_Temp['Max Temp Estimation'].loc[0]):
            Estimated_Max = Mx_o_Mx_Obs_Temp['Max Temp Estimation'].loc[0]
            Correlation_Max = Mx_o_Mx_Obs_Temp['Correlation Max T'].loc[0]
            
        else:
            #Now we need to check the correlation as the greater correlation will be the one to take hold, we want obs
            #To have the higher correlation first
            if (Mx_o_Mx_Obs_Temp['Correlation Max T'].loc[0] >= Mx_o_Mx_Est['Correlation Max T'].loc[0]):
                Estimated_Max = Mx_o_Mx_Obs_Temp['Max Temp Estimation'].loc[0]
                Correlation_Max = Mx_o_Mx_Obs_Temp['Correlation Max T'].loc[0]
            else:
                Estimated_Max = Mx_o_Mx_Est['Max Temp Estimation'].loc[0]
                Correlation_Max = Mx_o_Mx_Est['Correlation Max T'].loc[0]
    
     #------------------MIN-------------#
    #The first check is the highest correlation
    
    
    #First we choose the highest correlation as the initial condition
    Mx_o_Mn_Corr = data.loc[data['Correlation Min T'] == data['Correlation Min T'].max()]
    Mx_o_Mn_Corr = Mx_o_Mn_Corr.reset_index(drop = True)
    
    #Now we want to compare this Min temp Est to the min observed twmp of that day
    Mn_o_Mn_Obs_Temp = data.loc[data['temp'] == data['temp'].min()]
    Mn_o_Mn_Obs_Temp = Mn_o_Mn_Obs_Temp.reset_index(drop = True)
    
    #If proves that the highest correlation est is the highest value above any of the other obs temps
    #We can keep it if not
    if (Mx_o_Mn_Corr['Min Temp Estimation'].loc[0] <= Mn_o_Mn_Obs_Temp['temp'].loc[0]):
    
        Estimated_Min = Mx_o_Mn_Corr['Min Temp Estimation'].loc[0]
        Correlation_Min = Mx_o_Mn_Corr['Correlation Min T'].loc[0]
        
        
    else:
        #Now to see if the Est of the observed is the biggest estimation
        Mn_o_Mn_Est = data.loc[data['Min Temp Estimation'] == data['Min Temp Estimation'].min()]
        Mn_o_Mn_Est = Mx_o_Mn_Corr.reset_index(drop = True)
    
        #if it is keep this value as we know the max is the greatest that day
        if (Mn_o_Mn_Est['Min Temp Estimation'].loc[0] >= Mn_o_Mn_Obs_Temp['Min Temp Estimation'].loc[0]):
            Estimated_Min = Mn_o_Mn_Obs_Temp['Min Temp Estimation'].loc[0]
            Correlation_Min = Mn_o_Mn_Obs_Temp['Correlation Min T'].loc[0]
            
        else:
            #Now we need to check the correlation as the greater correlation will be the one to take hold, we want obs
            #To have the higher correlation first
            if (Mn_o_Mn_Obs_Temp['Correlation Min T'].loc[0] >= Mn_o_Mn_Est['Correlation Min T'].loc[0]):
                Estimated_Min = Mn_o_Mn_Obs_Temp['Min Temp Estimation'].loc[0]
                Correlation_Min = Mn_o_Mn_Obs_Temp['Correlation Min T'].loc[0]
            else:
                Estimated_Min = Mn_o_Mn_Est['Min Temp Estimation'].loc[0]
                Correlation_Min = Mn_o_Mn_Est['Correlation Min T'].loc[0]
    
print(Estimated_Max,Estimated_Min,Correlation_Max,Correlation_Min)
# Out:
# 27.011266968134176 15.040476821062637 0.9463847482489649 0.5796493014292508

# %%
#My Code should expect these to pop out
#length_1 =length_1.reset_index()
#From the code we expect Max Est: 29.4, Min Est: 18.1, Corr Max: 0.83, Corr Min: 0.80 #This workds
#length_2 =  length_2.reset_index()
#From the code we expect Max Est: 27.0, Min Est: 15.0, Corr Max: 0.95, Corr Min: 0.58
#length_3 =length_3.reset_index()
#From the code we expect Max Est: 30.1, Min Est: 18.2, Corr Max: 0.95, Corr Min: 0.87


#My code works now YESSSSS!!!!



PR_SEP
# Out:
#             hour 0  hour 1  hour 2  hour 3  hour 4  hour 5  hour 6  hour 7  \
# date
# 1967-09-01    10.6     NaN     NaN    11.6     NaN     NaN    11.1     NaN
# 1967-09-02    13.9     NaN     NaN    13.9     NaN     NaN    12.9     NaN
# 1967-09-03    13.3     NaN     NaN    11.2     NaN     NaN    10.4     NaN
# 1967-09-04    11.5     NaN     NaN     9.1     NaN     NaN     7.4     NaN
# 1967-09-05    11.6     NaN     NaN    11.7     NaN     NaN    10.9     NaN
# ...            ...     ...     ...     ...     ...     ...     ...     ...
# 1991-09-26    14.8     NaN     NaN    14.0     NaN     NaN    11.5     NaN
# 1991-09-27    14.5     NaN     NaN    14.4     NaN     NaN    13.5     NaN
# 1991-09-28    14.5     NaN     NaN    12.9     NaN     NaN    11.1     NaN
# 1991-09-29    14.9     NaN     NaN    13.5     NaN     NaN    12.6     NaN
# 1991-09-30    18.0     NaN     NaN    17.1     NaN     NaN    18.0     NaN
#
#             hour 8  hour 9  ...  hour 16  hour 17  hour 18  hour 19  hour 20  \
# date                        ...
# 1967-09-01     NaN    14.1  ...      NaN      NaN     16.0      NaN      NaN
# 1967-09-02     NaN    16.0  ...      NaN      NaN     14.8      NaN      NaN
# 1967-09-03     NaN    12.8  ...      NaN      NaN     14.5      NaN      NaN
# 1967-09-04     NaN    12.7  ...      NaN      NaN     17.2      NaN      NaN
# 1967-09-05     NaN    14.3  ...      NaN      NaN     19.5      NaN      NaN
# ...            ...     ...  ...      ...      ...      ...      ...      ...
# 1991-09-26     NaN    17.9  ...      NaN      NaN     18.2      NaN      NaN
# 1991-09-27     NaN    16.7  ...      NaN      NaN     18.0      NaN      NaN
# 1991-09-28     NaN    17.8  ...      NaN      NaN     19.5      NaN      NaN
# 1991-09-29     NaN    17.1  ...      NaN      NaN     18.0      NaN      NaN
# 1991-09-30     NaN    14.5  ...      NaN      NaN     13.7      NaN      NaN
#
#             hour 21  hour 22  hour 23  PRO Max  PRO Min
# date
# 1967-09-01     14.1      NaN      NaN     20.7     10.2
# 1967-09-02     13.9      NaN      NaN     18.9     12.2
# 1967-09-03     12.2      NaN      NaN     16.2     10.0
# 1967-09-04     13.4      NaN      NaN     19.7      6.7
# 1967-09-05     15.6      NaN      NaN     22.1     10.1
# ...             ...      ...      ...      ...      ...
# 1991-09-26     16.2      NaN      NaN     21.0     11.5
# 1991-09-27     15.8      NaN      NaN     21.4     12.8
# 1991-09-28     16.9      NaN      NaN     25.7     10.9
# 1991-09-29     17.9      NaN      NaN     21.4     12.2
# 1991-09-30     13.9      NaN      NaN     18.3     13.5
#
# [750 rows x 26 columns]

# %% [markdown]
# ## Making the functions and putting it all together

# %%
Columnn_Names = ['hour', PRO_Max]

#This is the full function put together to estimate max and min temps
def Historical_Daily_Extreme_Simple_Linear_Regression(Recent_Sub_Data, Recent_Extreme_Data, Hist_Sub_Daily, trials, 
                                                      Columnn_Names):
    '''
    The data needed:
    -Recent Sub-daily Data in a single column with the datetime that goes to hourly.
    -Historical Sub-daily Data in a single column with the datetime that goes to hourly.
    '''
    '''''' #This indicates that the code works
    
    
    '''#PART 1 is to split the recent_sub_daily data into each hour and then combine together this is a function.'''
    Recent_Sub_Data_Matrix = Sub_Daily_Splitter_To_Matrix(Recent_Sub_Data)
    
    '''# PART 2 Combine the Max and Min with the Subdaily'''
    Combined_Recent_Info = pd.merge(left = Recent_Sub_Data_Matrix, right  =Recent_Extreme_Data,
                                    left_index=True,right_index=True  )
    #Now Every Single Available hour and max and min is ready to be used.
    
    '''#PART 3 Is to split this data into each corresponding month'''
    Jan,Feb,Mar,Apr,May,Jun,Jul,Aug,Sep,Oct,Nov,Dec =  monther_splitter(Combined_Recent_Info)

    '''#PART 4 Is to fix up the Historical Data so it is closest to the every 3 hour mark.'''
    Hist_Sub_Daily_WT_Clos_Hour = Closest_Hour(Hist_Sub_Daily)
    
    #Part 5 Is to get each of the Month_Hour_Extreme separated for bootstrapping
    #Where we get the data from
    months = [Jan,Feb,Mar,Apr,May,Jun,Jul,Aug,Sep,Oct,Nov,Dec]
    hours = [0,3,6,9,12,18,21]
    extremes = ['Mx','Mn']
    Dictionary_Month_Separated, Keys = Dictionary_Separation(months,hours,extremes):
    
       
    #PART 6 Is to begin the bootstrapping and regression:
    
    
    
    
    
    
    
    
    
    
    
    
    
    #We start with the dictionary and use the call out the data first
    for data_used in Keys:
        Data = Dictionary_Month_Separated.get(data_used)
        
        #Lets do the initial run first and these will be the individual runs that will be added onto this matrix in the 
        
        #Sample the data
        individual_sampled=Data.sample(n=600,replace=True)
        #Reset_Index and delete date
        individual_sampled = individual_sampled.reset_index()
        del individual_sampled['date']
        
        # Part 7 For Each of the  Jan_0_Mx etc Now make a dictionary that picks samples of the Hour and Max 
        return(individual_sampled)
        
    
'''
We are bootstrapping the Hour X and Extremes for each month
Then we have to combine together so 

Jan_0_Mx = [Index  Hour_0_Run_1   Mx_0_Run_1... Hour_0_Run_1000    Mx_0_Run_1000
              1        19             25             28                 35

              2        20             26             15                 30      ]
              
              

              
              
#Then from here, we use Hour_0_Run_x and  Mx_0_Run_x to find Run_X a, b, corr

Then we combine this back by each run
Jan_Regression_Values_Max_Run_X = [Index        0              3               18                21
                               A        19             25             28                 35

                                B       20             26             15                 30      
                              Corr       .9            0.6    ...                                     ]
                              
#Then using this data we can go to the historical data and for each of these runs find the estimated temp using my
criteria above

Est Temp = 
[Index        Mean  Run 1  Run 2  Run 3 ...
   12/7/1937    17      13     15     20]
   
Corr= 
[Index         Mean Corr      Run 1  Run 2  Run 3 ...
   12/7/1937       0.8         .96     0.6     0.2]
                          








#Then for Run_x we find the max for that entire run by looking at all the other hours
              
              

'''
# Out:
#   Input In [16]
#     Dictionary_Month_Separated, Keys = Dictionary_Separation(months,hours,extremes):
#                                                                                    ^
# SyntaxError: invalid syntax

# %%
def Sub_Daily_Splitter_To_Matrix(Recent_Sub_Data): #COMPLETED
        
    PRO_Sub_0 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==0]],axis =0)
    PRO_Sub_3= pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==3]],axis =0)
    PRO_Sub_6= pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==6]],axis =0)
    PRO_Sub_9= pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==9]],axis =0)
    PRO_Sub_12= pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==12]],axis =0)
    PRO_Sub_15= pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==15]],axis =0)
    PRO_Sub_18= pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==18]],axis =0)
    PRO_Sub_21= pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==21]],axis =0)
    PRO_Sub_1 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==1]],axis =0)
    PRO_Sub_2 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==2]],axis =0)
    PRO_Sub_4 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==4]],axis =0)
    PRO_Sub_5 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==5]],axis =0)
    PRO_Sub_7 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==7]],axis =0)
    PRO_Sub_8 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==8]],axis =0)
    PRO_Sub_10 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==10]],axis =0)
    PRO_Sub_11 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==11]],axis =0)
    PRO_Sub_13 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==13]],axis =0)
    PRO_Sub_14 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==14]],axis =0)
    PRO_Sub_16 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==16]],axis =0)
    PRO_Sub_17 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==17]],axis =0)
    PRO_Sub_19 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==19]],axis =0)
    PRO_Sub_20 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==20]],axis =0)
    PRO_Sub_22 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==22]],axis =0)
    PRO_Sub_23 = pd.concat([PRO_Sub_ES[PRO_Sub_ES.index.hour==23]],axis =0)
    PRO_Sub_0 = PRO_Sub_0.reset_index()
    PRO_Sub_0['date'] = pd.to_datetime(PRO_Sub_0['date']).dt.date
    PRO_Sub_0 = PRO_Sub_0.set_index('date')
    PRO_Sub_3 = PRO_Sub_3.reset_index()
    PRO_Sub_3['date'] = pd.to_datetime(PRO_Sub_3['date']).dt.date
    PRO_Sub_3 = PRO_Sub_3.set_index('date')
    PRO_Sub_6 = PRO_Sub_6.reset_index()
    PRO_Sub_6['date'] = pd.to_datetime(PRO_Sub_6['date']).dt.date
    PRO_Sub_6 = PRO_Sub_6.set_index('date')
    PRO_Sub_9 = PRO_Sub_9.reset_index()
    PRO_Sub_9['date'] = pd.to_datetime(PRO_Sub_9['date']).dt.date
    PRO_Sub_9 = PRO_Sub_9.set_index('date')
    PRO_Sub_12 = PRO_Sub_12.reset_index()
    PRO_Sub_12['date'] = pd.to_datetime(PRO_Sub_12['date']).dt.date
    PRO_Sub_12 = PRO_Sub_12.set_index('date')
    PRO_Sub_15 = PRO_Sub_15.reset_index()
    PRO_Sub_15['date'] = pd.to_datetime(PRO_Sub_15['date']).dt.date
    PRO_Sub_15 = PRO_Sub_15.set_index('date')
    PRO_Sub_18 = PRO_Sub_18.reset_index()
    PRO_Sub_18['date'] = pd.to_datetime(PRO_Sub_18['date']).dt.date
    PRO_Sub_18 = PRO_Sub_18.set_index('date')
    PRO_Sub_21 = PRO_Sub_21.reset_index()
    PRO_Sub_21['date'] = pd.to_datetime(PRO_Sub_21['date']).dt.date
    PRO_Sub_21 = PRO_Sub_21.set_index('date')


    #Now make it its own DataFrame
    PRO_Sub_1 = PRO_Sub_1.reset_index()
    PRO_Sub_1['date'] = pd.to_datetime(PRO_Sub_1['date']).dt.date
    PRO_Sub_1 = PRO_Sub_1.set_index('date')
    PRO_Sub_2 = PRO_Sub_2.reset_index()
    PRO_Sub_2['date'] = pd.to_datetime(PRO_Sub_2['date']).dt.date
    PRO_Sub_2 = PRO_Sub_2.set_index('date')
    PRO_Sub_4 = PRO_Sub_4.reset_index()
    PRO_Sub_4['date'] = pd.to_datetime(PRO_Sub_4['date']).dt.date
    PRO_Sub_4 = PRO_Sub_4.set_index('date')
    PRO_Sub_5 = PRO_Sub_5.reset_index()
    PRO_Sub_5['date'] = pd.to_datetime(PRO_Sub_5['date']).dt.date
    PRO_Sub_5 = PRO_Sub_5.set_index('date')
    PRO_Sub_7 = PRO_Sub_7.reset_index()
    PRO_Sub_7['date'] = pd.to_datetime(PRO_Sub_7['date']).dt.date
    PRO_Sub_7 = PRO_Sub_7.set_index('date')
    PRO_Sub_8 = PRO_Sub_8.reset_index()
    PRO_Sub_8['date'] = pd.to_datetime(PRO_Sub_8['date']).dt.date
    PRO_Sub_8 = PRO_Sub_8.set_index('date')
    PRO_Sub_10 = PRO_Sub_10.reset_index()
    PRO_Sub_10['date'] = pd.to_datetime(PRO_Sub_10['date']).dt.date
    PRO_Sub_10 = PRO_Sub_10.set_index('date')
    PRO_Sub_11 = PRO_Sub_11.reset_index()
    PRO_Sub_11['date'] = pd.to_datetime(PRO_Sub_11['date']).dt.date
    PRO_Sub_11 = PRO_Sub_11.set_index('date')
    PRO_Sub_13 = PRO_Sub_13.reset_index()
    PRO_Sub_13['date'] = pd.to_datetime(PRO_Sub_13['date']).dt.date
    PRO_Sub_13 = PRO_Sub_13.set_index('date')
    PRO_Sub_14 = PRO_Sub_14.reset_index()
    PRO_Sub_14['date'] = pd.to_datetime(PRO_Sub_14['date']).dt.date
    PRO_Sub_14 = PRO_Sub_14.set_index('date')
    PRO_Sub_16 = PRO_Sub_16.reset_index()
    PRO_Sub_16['date'] = pd.to_datetime(PRO_Sub_16['date']).dt.date
    PRO_Sub_16 = PRO_Sub_16.set_index('date')
    PRO_Sub_17 = PRO_Sub_17.reset_index()
    PRO_Sub_17['date'] = pd.to_datetime(PRO_Sub_17['date']).dt.date
    PRO_Sub_17 = PRO_Sub_17.set_index('date')
    PRO_Sub_19 = PRO_Sub_19.reset_index()
    PRO_Sub_19['date'] = pd.to_datetime(PRO_Sub_19['date']).dt.date
    PRO_Sub_19 = PRO_Sub_19.set_index('date')
    PRO_Sub_20 = PRO_Sub_20.reset_index()
    PRO_Sub_20['date'] = pd.to_datetime(PRO_Sub_20['date']).dt.date
    PRO_Sub_20 = PRO_Sub_20.set_index('date')
    PRO_Sub_22 = PRO_Sub_22.reset_index()
    PRO_Sub_22['date'] = pd.to_datetime(PRO_Sub_22['date']).dt.date
    PRO_Sub_22 = PRO_Sub_22.set_index('date')
    PRO_Sub_23 = PRO_Sub_23.reset_index()
    PRO_Sub_23['date'] = pd.to_datetime(PRO_Sub_23['date']).dt.date
    PRO_Sub_23 = PRO_Sub_23.set_index('date')

    #Rename the columns
    PRO_Sub_0 = PRO_Sub_0.rename(columns={'temp':'hour 0'})
    PRO_Sub_3 = PRO_Sub_3.rename(columns={'temp':'hour 3'})
    PRO_Sub_6 = PRO_Sub_6.rename(columns={'temp':'hour 6'})
    PRO_Sub_9 = PRO_Sub_9.rename(columns={'temp':'hour 9'})
    PRO_Sub_12 = PRO_Sub_12.rename(columns={'temp':'hour 12'})
    PRO_Sub_15 = PRO_Sub_15.rename(columns={'temp':'hour 15'})
    PRO_Sub_18= PRO_Sub_18.rename(columns={'temp':'hour 18'})
    PRO_Sub_21 = PRO_Sub_21.rename(columns={'temp':'hour 21'})
    PRO_Sub_1 = PRO_Sub_1.rename(columns={'temp':'hour 1'})
    PRO_Sub_2 = PRO_Sub_2.rename(columns={'temp':'hour 2'})
    PRO_Sub_4 = PRO_Sub_4.rename(columns={'temp':'hour 4'})
    PRO_Sub_5 = PRO_Sub_5.rename(columns={'temp':'hour 5'})
    PRO_Sub_7 = PRO_Sub_7.rename(columns={'temp':'hour 7'})
    PRO_Sub_8 = PRO_Sub_8.rename(columns={'temp':'hour 8'})
    PRO_Sub_10= PRO_Sub_10.rename(columns={'temp':'hour 10'})
    PRO_Sub_11 = PRO_Sub_11.rename(columns={'temp':'hour 11'})
    PRO_Sub_13 = PRO_Sub_13.rename(columns={'temp':'hour 13'})
    PRO_Sub_14 = PRO_Sub_14.rename(columns={'temp':'hour 14'})
    PRO_Sub_16 = PRO_Sub_16.rename(columns={'temp':'hour 16'})
    PRO_Sub_17 = PRO_Sub_17.rename(columns={'temp':'hour 17'})
    PRO_Sub_19 = PRO_Sub_19.rename(columns={'temp':'hour 19'})
    PRO_Sub_20 = PRO_Sub_20.rename(columns={'temp':'hour 20'})
    PRO_Sub_22= PRO_Sub_22.rename(columns={'temp':'hour 22'})
    PRO_Sub_23 = PRO_Sub_23.rename(columns={'temp':'hour 23'})

    #Merge the data together
    #First Merge
    PR01 = pd.merge(PRO_Sub_0,PRO_Sub_1, on = ['date'], how  = 'left')
    PR23 = pd.merge(PRO_Sub_2,PRO_Sub_3, on = ['date'], how  = 'right')
    PR45 = pd.merge(PRO_Sub_4,PRO_Sub_5, on = ['date'], how  = 'right')
    PR67 = pd.merge(PRO_Sub_6,PRO_Sub_7, on = ['date'], how  = 'left')
    PR89 = pd.merge(PRO_Sub_8,PRO_Sub_9, on = ['date'], how  = 'right')
    PR1011 =pd.merge(PRO_Sub_10,PRO_Sub_11, on = ['date'], how  = 'right')
    PR1213 =pd.merge(PRO_Sub_12,PRO_Sub_13, on = ['date'], how  = 'left')
    PR1415 = pd.merge(PRO_Sub_14,PRO_Sub_15, on = ['date'], how  = 'right')
    PR1617 = pd.merge(PRO_Sub_16,PRO_Sub_17, on = ['date'], how  = 'right')
    PR1819 =pd.merge(PRO_Sub_18,PRO_Sub_19, on = ['date'], how  = 'left')
    PR2021 =pd.merge(PRO_Sub_20,PRO_Sub_21, on = ['date'], how  = 'right')
    PR2223 =pd.merge(PRO_Sub_22,PRO_Sub_23, on = ['date'], how  = 'right')

    #Second Merge
    PR0123 = pd.merge(PR01,PR23, on = ['date'], how  = 'left')
    PR4567 = pd.merge(PR45,PR67, on = ['date'], how  = 'right')
    PR891011 = pd.merge(PR89,PR1011, on = ['date'], how  = 'left')
    PR12131415 = pd.merge(PR1213,PR1415, on = ['date'], how  = 'left')
    PR16171819 = pd.merge(PR1617,PR1819, on = ['date'], how  = 'right')
    PR20212223 = pd.merge(PR2021,PR2223, on = ['date'], how  = 'left')

    #Third Merge
    PR_1 = pd.merge(PR0123,PR4567, on = ['date'], how  = 'left')
    PR_2 = pd.merge(PR891011,PR12131415, on = ['date'], how  = 'left')
    PR_3 = pd.merge(PR16171819,PR20212223, on = ['date'], how  = 'left')

    #Fourth Merge
    PR_L =  pd.merge(PR_1,PR_2, on = ['date'], how  = 'left')

    #Fifth Merge
    PR_FULL_MATRIX =  pd.merge(PR_L,PR_3, on = ['date'], how  = 'left')

    #Clean Data Up
    PR_FULL_MATRIX = PR_FULL_MATRIX.reset_index()
    PR_FULL_MATRIX['date'] = pd.to_datetime(PR_FULL_MATRIX['date'])
    PR_FULL_MATRIX = PR_FULL_MATRIX.set_index('date')

    return(PR_FULL_MATRIX)

# %%
# Function that splits it into each month
def monther_splitter(data): #COMPLETED
    #From the matrix of the recent year, it gets all the information for that month into a single matrix
    Jan = pd.concat([data[data.index.month==1],], axis = 0)
    Feb = pd.concat([data[data.index.month==2],], axis = 0)
    Mar = pd.concat([data[data.index.month==3],], axis = 0)
    Apr = pd.concat([data[data.index.month==4],], axis = 0)
    May = pd.concat([data[data.index.month==5],], axis = 0)
    Jun = pd.concat([data[data.index.month==6],], axis = 0)
    Jul = pd.concat([data[data.index.month==7],], axis = 0)
    Aug = pd.concat([data[data.index.month==8],], axis = 0)
    Sep = pd.concat([data[data.index.month==9],], axis = 0)
    Oct = pd.concat([data[data.index.month==10],], axis = 0)
    Nov = pd.concat([data[data.index.month==11],], axis = 0)
    Dec = pd.concat([data[data.index.month==12],], axis = 0)
    return(Jan,Feb,Mar,Apr,May,Jun,Jul,Aug,Sep,Oct,Nov,Dec)

# %%
def take_closest(myList, myNumber): #COMPLETED
    """
    Assumes myList is sorted. Returns closest value to myNumber.

    If two numbers are equally close, return the smallest number.
    """
    pos = bisect_left(myList, myNumber)
    if pos == 0:
        return myList[0]
    if pos == len(myList):
        return myList[-1]
    before = myList[pos - 1]
    after = myList[pos]
    if after - myNumber < myNumber - before:
        return after
    else:
        return before

# %%
def Closest_Hour(Data): #COMPLETED
    closest_hour= []
    
    #We want to match to the hour closest to the 3s
    hours = pd.Series([0,3,6,9,12,15,18,21,24])

    for i in range(len(Data)):
        Individual_Day = Data.loc[i]
    
        #Extract hour
        Individual_Hour = Individual_Day['date'].hour
    
        Closest_Ind_Hour = take_closest(hours, Individual_Hour)
        closest_hour.append(Closest_Ind_Hour)
    
    #Add it as a series then combine to make it a dataframe
    CL = pd.Series(closest_hour, name = 'Closest Hour')

    Data = pd.merge(left = Data,right  =CL,left_index=True,right_index=True  )
    return(Data)

# %%
#Sample function

def sampler_month_hour(Month_Data, Hour): #COMPLETED
   
    
    
    
    return(Month_Data_Hour,Month_Data_Hour_Min)

# %% [markdown]
# Present Heatwave differently
# 7 years out of 10 or equiv number of months
# wieght results by that
#
# Heatwave freq per year/8 years in 1940s
# much more robust same
#
# can calc heatwave stat reliable for given season
#
# if ask someone to help, they can be an author
#
# acknowledge alex and ruby etc

# %%
#Now develop the linear regression equation
def linear_regression_polyfit(x,y):
    #FInd the linear Relationship
    A, B = np.polyfit(x, y, 1)
    #Find the correlation                  
    corr, _ = pearsonr(x, y)
    return(A,B,corr)

# %%
def Dictionary_Separation(months_Data,hours_Data,months_Names,Extreme_Column_Names): #COMPLETED
    #Where we place all the data into
    Sub_Daily_Matrix_Full_Sampled_Dic = {}
    #Wjere we place all the dictorionary titles in
    Keys = []
    for month in range(len(months_Data)):
        for hour in hours_Data:
            key1 = months_Names[month] + "_" + str(hour)+ "_" + "Mx"
            key2 = months_Names[month] + "_" + str(hour)+ "_" + "Mn"
        
            #Put It in the dictionary
            Sub_Daily_Matrix_Full_Sampled_Dic[key1] = months_Data[month][['hour {}'.format(hour), Extreme_Column_Names[0]]]
            #Drop the Nans
            Sub_Daily_Matrix_Full_Sampled_Dic[key1] = Sub_Daily_Matrix_Full_Sampled_Dic[key1].dropna(subset=['hour {}'.format(hour), Extreme_Column_Names[0]])
            
        
            Sub_Daily_Matrix_Full_Sampled_Dic[key2] = months_Data[month][['hour {}'.format(hour), Extreme_Column_Names[1]]]
            #Drop the Nans
            Sub_Daily_Matrix_Full_Sampled_Dic[key2] = Sub_Daily_Matrix_Full_Sampled_Dic[key2].dropna(subset=['hour {}'.format(hour), Extreme_Column_Names[1]])
        
            Keys.append(key1)
            Keys.append(key2)
        
    return(Sub_Daily_Matrix_Full_Sampled_Dic,Keys)

# %% [markdown]
# ## TESTING THE FUNCTION SEQUENCE SO I KNOW IT WORKS

# %%
#Now load in and fix Perth Gardens 1830-1875
Per_Gard = pd.read_csv(r"E:\LIBRARY\UNIVERSITY\Masters Research\Python\Data\swanriver_subdaily_1830-1875.csv")
Per_Gard
#Set Datetime
Per_Gard['date'] = pd.to_datetime(Per_Gard['date'],dayfirst = True)


closest_hour= []
#We want to match to the hour closest to the 3s
hours = pd.Series([0,3,6,9,12,15,18,21,24])

for i in range(len(Per_Gard)):
    Individual_Day = Per_Gard.loc[i]
    
    #Extract hour
    Individual_Hour = Individual_Day['date'].hour
    
    Closest_Ind_Hour = take_closest(hours, Individual_Hour)
    closest_hour.append(Closest_Ind_Hour)
    
#Add it as a series then combine to make it a dataframe
CL = pd.Series(closest_hour, name = 'Closest hour')

Per_Gard = pd.merge(left = Per_Gard,right  =CL,left_index=True,right_index=True  )
    

#So this works, now we need to expand this into a for loop and make this a new dataframe to be added onto
#the historical time because it will make things easier



#Can't set index yet.
#Perth Regional Office 1967 to 1992 sub daily dataset
PRO_Sub = pd.read_csv(r"E:\LIBRARY\UNIVERSITY\Masters Research\Python\Data\perthregionaloffice_subdaily_1942-1992.csv")

PRO_Sub['date'] = pd.to_datetime(PRO_Sub['date'],dayfirst = True)
PRO_Sub = PRO_Sub.set_index('date')
PRO_Sub =PRO_Sub['temp']/10 

PRO_Sub_ES  = PRO_Sub.loc['1967':'1992']
PRO_Sub_ES =PRO_Sub_ES

## Perth Regional Office Daily Extreme Dataset
#Load PRO in
#BOM PERTH REGIONAL OFFICE
MaxT_PRO = pd.read_csv(r"E:\LIBRARY\UNIVERSITY\Masters Research\Python\Data\IDCJAC0010_009034_1800_Data.csv")
MinT_PRO = pd.read_csv(r"E:\LIBRARY\UNIVERSITY\Masters Research\Python\Data\IDCJAC0011_009034_1800_Data.csv")

#Clean The data
MaxT_PRO['Datetime']= pd.to_datetime(MaxT_PRO[['Year', 'Month', 'Day']])
MinT_PRO['Datetime']= pd.to_datetime(MinT_PRO[['Year', 'Month', 'Day']])

#Delete irrelevent columns
del MaxT_PRO['Product code']
del MaxT_PRO['Bureau of Meteorology station number']
del MaxT_PRO['Year']
del MaxT_PRO['Month']
del MaxT_PRO['Day']
del MaxT_PRO['Days of accumulation of maximum temperature']
del MaxT_PRO['Quality']
del MinT_PRO['Product code']
del MinT_PRO['Bureau of Meteorology station number']
del MinT_PRO['Year']
del MinT_PRO['Month']
del MinT_PRO['Day']
del MinT_PRO['Days of accumulation of minimum temperature']
del MinT_PRO['Quality']

#Change the column name to date
MaxT_PRO= MaxT_PRO.rename(columns={'Datetime':'date'})
MinT_PRO= MinT_PRO.rename(columns={'Datetime':'date'})


#Change the column names
MaxT_PRO= MaxT_PRO.rename(columns={'Maximum temperature (Degree C)':'PRO Max'})
MinT_PRO= MinT_PRO.rename(columns={'Minimum temperature (Degree C)':'PRO Min'})

#Now concat it
MaxT_PRO= MaxT_PRO.set_index('date')
MinT_PRO= MinT_PRO.set_index('date')

PRO_DE = pd.merge(left = MaxT_PRO,right  =MinT_PRO,left_index=True,right_index=True  )


Samples = 30
Trials = 2

# %%
#Historical_Daily_Extreme_Simple_Linear_Regression(Recent_Sub_Data, Recent_Extreme_Data, Hist_Sub_Daily, trials, Columnn_Names)
Recent_Sub_Data = PRO_Sub_ES
Recent_Extreme_Data = PRO_DE
#Closest Hour hasnt been done on it yet
Hist_Sub_Daily = Per_Gard

# %%
#PART 1 is to split the recent_sub_daily data into each hour and then combine together this is a function.
Recent_Sub_Data_Matrix = Sub_Daily_Splitter_To_Matrix(Recent_Sub_Data)

# %%
# PART 2 Combine the Max and Min with the Subdaily
Combined_Recent_Info = pd.merge(left = Recent_Sub_Data_Matrix, right  =Recent_Extreme_Data,
                                    left_index=True,right_index=True  )
#Now Every Single Available hour and max and min is ready to be used.

# %%
#PART 3 Is to split this data into each corresponding month
Jan,Feb,Mar,Apr,May,Jun,Jul,Aug,Sep,Oct,Nov,Dec =  monther_splitter(Combined_Recent_Info)

# %%
#PART 4 Is to fix up the Historical Data so it is closest to the every 3 hour mark.
Hist_Sub_Daily_WT_Clos_Hour = Closest_Hour(Hist_Sub_Daily)

# %%
#Part 5 Is to get each of the Month_Hour_Extreme separated for bootstrapping
#Where we get the data from
months_Data = [Jan,Feb,Mar,Apr,May,Jun,Jul,Aug,Sep,Oct,Nov,Dec]
hours_Data =  [0,3,6,9,12,15,18,21]
months_Names = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
Extreme_Column_Names = ['PRO Max','PRO Min']

Dictionary_Month_Separated, Keys = Dictionary_Separation(months_Data,hours_Data,months_Names,Extreme_Column_Names)

# %% [markdown]
# We have 3 columns, the date, the hour 0 and the PRO Max etc

# %%
#PART 6
#Now I need to select 600 points and trail it 1000 times for each single thing in the dictionary and label the hour 0 as hour 0 run 1]
#and PRO Max Run 1
Dictionary_Dataset= Dictionary_Month_Separated
Keys_for_Dic = Keys


#Get useful data ready
Sampled_Dictionary = {}  
Keys_Sampled = []


#Firstly extract that part of the dictionary to be used
for keys_used in Keys_for_Dic:
    #Extract Data
    Data = Dictionary_Dataset.get(keys_used)
    
    #The sampling
    #So we get a new dataset so it doesnt replace the original values
    #Do a single run so it appends to the RUNS
    Run1_Data = Data.sample(n=Samples,replace=True)
    #Drop the date column
    Run1_Data = Run1_Data.reset_index(drop = True)
    #Index is 0 to 9, or 0 to Samples-1
    #Get the columns names
    Col = Run1_Data.columns
    
    #Now change column name to make it run 1 etc
    Run1_Data= Run1_Data.rename(columns={Col[0]:Col[0] + ' ' +  'run 1'})
    Run_Data= Run1_Data.rename(columns={Col[1]:Col[1] + ' ' +  'run 1'})
    

    #Now develope the for loop
    for rns in range(2,Trials+1):
        #This is the now the random sampling for 1000 different samples of 600 
        Individual_Run = Data.sample(n=Samples,replace=True)
        #Drop the date column
        Individual_Run = Individual_Run.reset_index(drop = True)
        #Index is 0 to 9, or 0 to Samples-1
        #Get the columns names
        Col = Individual_Run.columns
        
        #Now change column name to make it run 1 etc
        Individual_Run= Individual_Run.rename(columns={Col[0]:Col[0] + ' ' +  'run {}'.format(rns)})
        Individual_Run= Individual_Run.rename(columns={Col[1]:Col[1] + ' ' +  'run {}'.format(rns)})
        
        #Concate with RUNS
        Run_Data = pd.concat([Run_Data, Individual_Run],axis=1)
    #Now create a new dictionary that uses the name of the old dictorinary + sampling to put these runs into
    
    
    

    key = keys_used + "_" + "Sampled"
    
    #Add it in the dictionary
    Sampled_Dictionary[key] = Run_Data
    
    Keys_Sampled.append(key)

# %%
#This is what I need to get to
'''
TITLE: OCT_RUN_1
INDEX    TIME    A    B    CORR 
0          0 
1          3
2          6
3          9
4          12
5          15
6          18
7          21

TITLE: OCT_RUN_2
TIME    A    B    CORR 
0 
3
6
9
12
15
18
21

TITLE: OCT_RUN_3
TIME    A    B    CORR 
0 
3
6
9
12
15
18
21

TITLE: OCT_RUN_4
TIME    A    B    CORR 
0 
3
6
9
12
15
18
21

'''
# Out:
# '\nTITLE: OCT_RUN_1\nINDEX    TIME    A    B    CORR \n0          0 \n1          3\n2          6\n3          9\n4          12\n5          15\n6          18\n7          21\n\nTITLE: OCT_RUN_2\nTIME    A    B    CORR \n0 \n3\n6\n9\n12\n15\n18\n21\n\nTITLE: OCT_RUN_3\nTIME    A    B    CORR \n0 \n3\n6\n9\n12\n15\n18\n21\n\nTITLE: OCT_RUN_4\nTIME    A    B    CORR \n0 \n3\n6\n9\n12\n15\n18\n21\n\n'

# %%
#Now to apply the regression anaylsis onto the data I have provide

#Lets do it for the run and then build it onto that
hour_Data = [0,3,6,9,12,15,18,21]
#Get useful data ready
Reg_Trial_Data = {}
All_data = {}
Key_Outer = []
Key_Inner = []

Month_Name = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']


for month_num in range(0,12):
    #Extract the month name
    Month_Str =  Month_Name[month_num]  
    #Go by trail first
    for trial_number in range(1,Trials+1):
        #----MAX---#
        #Load each hour in for that Month
        Mxt_0 = Sampled_Dictionary.get('{}'.format(Month_Str)+'_0_Mx_Sampled')
        #Function that finds A,B,corr for that trial
        A0,B0,corr0 = linear_regression_polyfit(Mxt_0['hour 0 run {}'.format(trial_number)],Mxt_0['PRO Max run {}'.format(trial_number)])
    
        Mxt_3 = Sampled_Dictionary.get('{}'.format(Month_Str)+'_3_Mx_Sampled')
        #Function that finds A,B,corr for that trial
        A3,B3,corr3 = linear_regression_polyfit(Mxt_3['hour 3 run {}'.format(trial_number)],Mxt_3['PRO Max run {}'.format(trial_number)])
    
    
        Mxt_6 = Sampled_Dictionary.get('{}'.format(Month_Str)+'_6_Mx_Sampled')
        #Function that finds A,B,corr for that trial
        A6,B6,corr6 = linear_regression_polyfit(Mxt_6['hour 6 run {}'.format(trial_number)],Mxt_6['PRO Max run {}'.format(trial_number)])
    
        Mxt_9 = Sampled_Dictionary.get('{}'.format(Month_Str)+'_9_Mx_Sampled')
        #Function that finds A,B,corr for that trial
        A9,B9,corr9 = linear_regression_polyfit(Mxt_9['hour 9 run {}'.format(trial_number)],Mxt_9['PRO Max run {}'.format(trial_number)])
    
    
        Mxt_12 = Sampled_Dictionary.get('{}'.format(Month_Str)+'_12_Mx_Sampled')
        #Function that finds A,B,corr for that trial
        A12,B12,corr12 = linear_regression_polyfit(Mxt_12['hour 12 run {}'.format(trial_number)],Mxt_12['PRO Max run {}'.format(trial_number)])
    
        Mxt_12 = Sampled_Dictionary.get('{}'.format(Month_Str)+'_12_Mx_Sampled')
        #Function that finds A,B,corr for that trial
        A12,B12,corr12 = linear_regression_polyfit(Mxt_12['hour 12 run {}'.format(trial_number)],Mxt_12['PRO Max run {}'.format(trial_number)])
    
    
        Mxt_15 = Sampled_Dictionary.get('{}'.format(Month_Str)+'_15_Mx_Sampled')
        #Function that finds A,B,corr for that trial
        A15,B15,corr15 = linear_regression_polyfit(Mxt_15['hour 15 run {}'.format(trial_number)],Mxt_15['PRO Max run {}'.format(trial_number)])
    
        Mxt_18 = Sampled_Dictionary.get('{}'.format(Month_Str)+'_18_Mx_Sampled')
        #Function that finds A,B,corr for that trial
        A18,B18,corr18 = linear_regression_polyfit(Mxt_18['hour 18 run {}'.format(trial_number)],Mxt_18['PRO Max run {}'.format(trial_number)])
    
        Mxt_21 = Sampled_Dictionary.get('{}'.format(Month_Str)+'_21_Mx_Sampled')
        #Function that finds A,B,corr for that trial
        A21,B21,corr21 = linear_regression_polyfit(Mxt_21['hour 21 run {}'.format(trial_number)],Mxt_21['PRO Max run {}'.format(trial_number)])
    
        
        Time = pd.Series(hour_Data,name = 'Hours') 
        A = pd.Series([A0,A3,A6,A9,A12,A15,A18,A21],name = 'A')
        B = pd.Series([B0,B3,B6,B9,B12,B15,B18,B21],name = 'B')
        corr = pd.Series([corr0,corr3,corr6,corr9,corr12,corr15,corr18,corr21],name = 'CORR')
        Items = pd.concat([Time,A,B,corr],axis = 1)
    
    
        key1 =  "{}".format(Month_Str) + "_" + 'Trial'+ "_" + str(trial_number) + "_" + "Mx"
        Reg_Trial_Data[key1] = Items
    
        Key_Inner.append(key1)
    
    
        #---MIN---#
        Mnt_0 = Sampled_Dictionary.get('{}'.format(Month_Str)+'_0_Mn_Sampled')
        #Function that finds A,B,corr for that trial
        A0,B0,corr0 = linear_regression_polyfit(Mnt_0['hour 0 run {}'.format(trial_number)],Mnt_0['PRO Min run {}'.format(trial_number)])
    
        Mnt_3 = Sampled_Dictionary.get('{}'.format(Month_Str)+'_3_Mn_Sampled')
        #Function that finds A,B,corr for that trial
        A3,B3,corr3 = linear_regression_polyfit(Mnt_3['hour 3 run {}'.format(trial_number)],Mnt_3['PRO Min run {}'.format(trial_number)])
    
    
        Mnt_6 = Sampled_Dictionary.get('{}'.format(Month_Str)+'_6_Mn_Sampled')
        #Function that finds A,B,corr for that trial
        A6,B6,corr6 = linear_regression_polyfit(Mnt_6['hour 6 run {}'.format(trial_number)],Mnt_6['PRO Min run {}'.format(trial_number)])
    
        Mnt_9 = Sampled_Dictionary.get('{}'.format(Month_Str)+'_9_Mn_Sampled')
        #Function that finds A,B,corr for that trial
        A9,B9,corr9 = linear_regression_polyfit(Mnt_9['hour 9 run {}'.format(trial_number)],Mnt_9['PRO Min run {}'.format(trial_number)])
    
    
        Mnt_12 = Sampled_Dictionary.get('{}'.format(Month_Str)+'_12_Mn_Sampled')
        #Function that finds A,B,corr for that trial
        A12,B12,corr12 = linear_regression_polyfit(Mnt_12['hour 12 run {}'.format(trial_number)],Mnt_12['PRO Min run {}'.format(trial_number)])
    
        Mnt_12 = Sampled_Dictionary.get('{}'.format(Month_Str)+'_12_Mn_Sampled')
        #Function that finds A,B,corr for that trial
        A12,B12,corr12 = linear_regression_polyfit(Mnt_12['hour 12 run {}'.format(trial_number)],Mnt_12['PRO Min run {}'.format(trial_number)])
    
    
        Mnt_15 = Sampled_Dictionary.get('{}'.format(Month_Str)+'_15_Mn_Sampled')
        #Function that finds A,B,corr for that trial
        A15,B15,corr15 = linear_regression_polyfit(Mnt_15['hour 15 run {}'.format(trial_number)],Mnt_15['PRO Min run {}'.format(trial_number)])
    
        Mnt_18 = Sampled_Dictionary.get('{}'.format(Month_Str)+'_18_Mn_Sampled')
        #Function that finds A,B,corr for that trial
        A18,B18,corr18 = linear_regression_polyfit(Mnt_18['hour 18 run {}'.format(trial_number)],Mnt_18['PRO Min run {}'.format(trial_number)])
    
        Mnt_21 = Sampled_Dictionary.get('{}'.format(Month_Str)+'_21_Mn_Sampled')
        #Function that finds A,B,corr for that trial
        A21,B21,corr21 = linear_regression_polyfit(Mnt_21['hour 21 run {}'.format(trial_number)],Mnt_21['PRO Min run {}'.format(trial_number)])
    
        
        Time = pd.Series(hour_Data,name = 'Hours') 
        A = pd.Series([A0,A3,A6,A9,A12,A15,A18,A21],name = 'A')
        B = pd.Series([B0,B3,B6,B9,B12,B15,B18,B21],name = 'B')
        corr = pd.Series([corr0,corr3,corr6,corr9,corr12,corr15,corr18,corr21],name = 'CORR')
        Items2 = pd.concat([Time,A,B,corr],axis = 1)
    
    
        key2 =  "{}".format(Month_Str) + "_" + 'Trial'+ "_" + str(trial_number) + "_" + "Mn"
        Reg_Trial_Data[key2] = Items2
        Key_Inner.append(key2)
        
    key3 =  "{}".format(Month_Str) 
    All_data[key3] = Reg_Trial_Data
    Key_Outer.append(key3)

# %%
def estimation_ind_day_function(MONTH, Hour, Temp, DATA_4_EST, Trial_Number):
    Trial_Number =  Trial_Number +1
    if (MONTH == 1):
        #Find Index Closest to Hour
        Index_Found = np.divide(Hour,3)
        if (Index_Found == 8):
            Index_Found = 0
        else:
            Index_Found = Index_Found
            
        #Estimate Max
        Information_Max = DATA_4_EST.get('Jan').get('Jan_Trial_{}_Mx'.format(Trial_Number)).loc[int(Index_Found)]
        Est_Max = Information_Max['A']*Temp + (Information_Max['B'])
        Correlation_Max =  Information_Max['CORR']
    
        #Estimate Min
        Information_Min = DATA_4_EST.get('Jan').get('Jan_Trial_{}_Mn'.format(Trial_Number)).loc[int(Index_Found)]
        Est_Min = Information_Min['A']*Temp + (Information_Min['B'])
        Correlation_Min =  Information_Min['CORR']
        
        
    elif (MONTH == 2):
        #Find Index Closest to Hour
        Index_Found = np.divide(Hour,3)
        if (Index_Found == 8):
            Index_Found = 0
        else:
            Index_Found = Index_Found
    
    
        #Estimate Max
        Information_Max = DATA_4_EST.get('Feb').get('Feb_Trial_{}_Mx'.format(Trial_Number)).loc[int(Index_Found)]
        Est_Max = Information_Max['A']*Temp + (Information_Max['B'])
        Correlation_Max =  Information_Max['CORR']
    
        #Estimate Min
        Information_Min = DATA_4_EST.get('Feb').get('Feb_Trial_{}_Mn'.format(Trial_Number)).loc[int(Index_Found)]
        Est_Min = Information_Min['A']*Temp + (Information_Min['B'])
        Correlation_Min =  Information_Min['CORR']
        
    
    elif (MONTH == 3):
        #Find Index Closest to Hour
        Index_Found = np.divide(Hour,3)
        if (Index_Found == 8):
            Index_Found = 0
        else:
            Index_Found = Index_Found
    
        #Estimate Max
        Information_Max = DATA_4_EST.get('Mar').get('Mar_Trial_{}_Mx'.format(Trial_Number)).loc[int(Index_Found)]
        Est_Max = Information_Max['A']*Temp + (Information_Max['B'])
        Correlation_Max =  Information_Max['CORR']
    
        #Estimate Min
        Information_Min = DATA_4_EST.get('Mar').get('Mar_Trial_{}_Mn'.format(Trial_Number)).loc[int(Index_Found)]
        Est_Min = Information_Min['A']*Temp + (Information_Min['B'])
        Correlation_Min =  Information_Min['CORR']
        
    elif (MONTH == 4):
        #Find Index Closest to Hour
        Index_Found = np.divide(Hour,3)
        if (Index_Found == 8):
            Index_Found = 0
        else:
            Index_Found = Index_Found
    
        #Estimate Max
        Information_Max = DATA_4_EST.get('Apr').get('Apr_Trial_{}_Mx'.format(Trial_Number)).loc[int(Index_Found)]
        Est_Max = Information_Max['A']*Temp + (Information_Max['B'])
        Correlation_Max =  Information_Max['CORR']
    
        #Estimate Min
        Information_Min = DATA_4_EST.get('Apr').get('Apr_Trial_{}_Mn'.format(Trial_Number)).loc[int(Index_Found)]
        Est_Min = Information_Min['A']*Temp + (Information_Min['B'])
        Correlation_Min =  Information_Min['CORR']
        
    elif (MONTH == 5):
        #Find Index Closest to Hour
        Index_Found = np.divide(Hour,3)
        if (Index_Found == 8):
            Index_Found = 0
        else:
            Index_Found = Index_Found
    
        #Estimate Max
        Information_Max = DATA_4_EST.get('May').get('May_Trial_{}_Mx'.format(Trial_Number)).loc[int(Index_Found)]
        Est_Max = Information_Max['A']*Temp + (Information_Max['B'])
        Correlation_Max =  Information_Max['CORR']
    
        #Estimate Min
        Information_Min = DATA_4_EST.get('May').get('May_Trial_{}_Mn'.format(Trial_Number)).loc[int(Index_Found)]
        Est_Min = Information_Min['A']*Temp + (Information_Min['B'])
        Correlation_Min =  Information_Min['CORR']
        
    elif (MONTH == 6):
        #Find Index Closest to Hour
        Index_Found = np.divide(Hour,3)
        if (Index_Found == 8):
            Index_Found = 0
        else:
            Index_Found = Index_Found
        #Estimate Max
        Information_Max = DATA_4_EST.get('Jun').get('Jun_Trial_{}_Mx'.format(Trial_Number)).loc[int(Index_Found)]
        Est_Max = Information_Max['A']*Temp + (Information_Max['B'])
        Correlation_Max =  Information_Max['CORR']
    
        #Estimate Min
        Information_Min = DATA_4_EST.get('Jun').get('Jun_Trial_{}_Mn'.format(Trial_Number)).loc[int(Index_Found)]
        Est_Min = Information_Min['A']*Temp + (Information_Min['B'])
        Correlation_Min =  Information_Min['CORR']
        
    elif (MONTH == 7):
        #Find Index Closest to Hour
        Index_Found = np.divide(Hour,3)
        if (Index_Found == 8):
            Index_Found = 0
        else:
            Index_Found = Index_Found
        #Estimate Max
        Information_Max = DATA_4_EST.get('Jul').get('Jul_Trial_{}_Mx'.format(Trial_Number)).loc[int(Index_Found)]
        Est_Max = Information_Max['A']*Temp + (Information_Max['B'])
        Correlation_Max =  Information_Max['CORR']
    
        #Estimate Min
        Information_Min = DATA_4_EST.get('Jul').get('Jul_Trial_{}_Mn'.format(Trial_Number)).loc[int(Index_Found)]
        Est_Min = Information_Min['A']*Temp + (Information_Min['B'])
        Correlation_Min =  Information_Min['CORR']
        
        
    elif (MONTH == 8):
        #Find Index Closest to Hour
        Index_Found = np.divide(Hour,3)
        if (Index_Found == 8):
            Index_Found = 0
        else:
            Index_Found = Index_Found
        #Estimate Max
        Information_Max = DATA_4_EST.get('Aug').get('Aug_Trial_{}_Mx'.format(Trial_Number)).loc[int(Index_Found)]
        Est_Max = Information_Max['A']*Temp + (Information_Max['B'])
        Correlation_Max =  Information_Max['CORR']
    
        #Estimate Min
        Information_Min = DATA_4_EST.get('Aug').get('Aug_Trial_{}_Mn'.format(Trial_Number)).loc[int(Index_Found)]
        Est_Min = Information_Min['A']*Temp + (Information_Min['B'])
        Correlation_Min =  Information_Min['CORR']
    
    elif (MONTH == 9):
        #Find Index Closest to Hour
        Index_Found = np.divide(Hour,3)
        if (Index_Found == 8):
            Index_Found = 0
        else:
            Index_Found = Index_Found
        #Estimate Max
        Information_Max = DATA_4_EST.get('Sep').get('Sep_Trial_{}_Mx'.format(Trial_Number)).loc[int(Index_Found)]
        Est_Max = Information_Max['A']*Temp + (Information_Max['B'])
        Correlation_Max =  Information_Max['CORR']
    
        #Estimate Min
        Information_Min = DATA_4_EST.get('Sep').get('Sep_Trial_{}_Mn'.format(Trial_Number)).loc[int(Index_Found)]
        Est_Min = Information_Min['A']*Temp + (Information_Min['B'])
        Correlation_Min =  Information_Min['CORR']
        
        
    elif (MONTH == 10):
        #Find Index Closest to Hour
        Index_Found = np.divide(Hour,3)
        if (Index_Found == 8):
            Index_Found = 0
        else:
            Index_Found = Index_Found
        #Estimate Max
        Information_Max = DATA_4_EST.get('Oct').get('Oct_Trial_{}_Mx'.format(Trial_Number)).loc[int(Index_Found)]
        Est_Max = Information_Max['A']*Temp + (Information_Max['B'])
        Correlation_Max =  Information_Max['CORR']
    
        #Estimate Min
        Information_Min = DATA_4_EST.get('Oct').get('Oct_Trial_{}_Mn'.format(Trial_Number)).loc[int(Index_Found)]
        Est_Min = Information_Min['A']*Temp + (Information_Min['B'])
        Correlation_Min =  Information_Min['CORR']
    
    elif (MONTH == 11):
        #Find Index Closest to Hour
        Index_Found = np.divide(Hour,3)
        if (Index_Found == 8):
            Index_Found = 0
        else:
            Index_Found = Index_Found
        #Estimate Max
        Information_Max = DATA_4_EST.get('Nov').get('Nov_Trial_{}_Mx'.format(Trial_Number)).loc[int(Index_Found)]
        Est_Max = Information_Max['A']*Temp + (Information_Max['B'])
        Correlation_Max =  Information_Max['CORR']
    
        #Estimate Min
        Information_Min = DATA_4_EST.get('Nov').get('Nov_Trial_{}_Mn'.format(Trial_Number)).loc[int(Index_Found)]
        Est_Min = Information_Min['A']*Temp + (Information_Min['B'])
        Correlation_Min =  Information_Min['CORR']
    
    else:
        #Find Index Closest to Hour
        Index_Found = np.divide(Hour,3)
        if (Index_Found == 8):
            Index_Found = 0
        else:
            Index_Found = Index_Found
            
            
        #Estimate Max
        Information_Max = DATA_4_EST.get('Dec').get('Dec_Trial_{}_Mx'.format(Trial_Number)).loc[int(Index_Found)]
        Est_Max = Information_Max['A']*Temp + (Information_Max['B'])
        Correlation_Max =  Information_Max['CORR']
    
        #Estimate Min
        Information_Min = DATA_4_EST.get('Dec').get('Dec_Trial_{}_Mn'.format(Trial_Number)).loc[int(Index_Found)]
        Est_Min = Information_Min['A']*Temp + (Information_Min['B'])
        Correlation_Min =  Information_Min['CORR']
        
    return(Est_Max,Est_Min,Correlation_Max,Correlation_Min)

# %%
def estimation_single_date_temp_Complex(data):
  
    #Single Case: Most simple
    if (len(data) == 1):
        #This finds the values required for a length of 1 data
        Estimated_Max = data['Max Temp Estimation'].loc[0]
        Estimated_Min = data['Min Temp Estimation'].loc[0]
        Correlation_Max = data['Correlation Max T'].loc[0]
        Correlation_Min = data['Correlation Min T'].loc[0]


    elif (len(data) == 2):
        #--------- MAX ------------#
        #Doing something more complicated
        #First lets find the max of the correlation for the max and min
    
        #nOW FOR TWO INDICES
        #First we choose the highest correlation as the initial condition
        Mx_o_Mx_Corr = data.loc[data['Correlation Max T'] == data['Correlation Max T'].max()]
        Mx_o_Mx_Corr = Mx_o_Mx_Corr.reset_index(drop = True)
    
        #Now we want to compare this Max temp Est to the max observed twmp of that day
        Mx_o_Mx_Obs_Temp = data.loc[data['temp'] == data['temp'].max()]
        Mx_o_Mx_Obs_Temp = Mx_o_Mx_Obs_Temp.reset_index(drop = True)
    
        #Check if Est is greater or equal to the Obs, this is to ensure that the highest correlation is kept
        if (Mx_o_Mx_Corr['Max Temp Estimation'].loc[0] >= Mx_o_Mx_Obs_Temp['temp'].loc[0]):
            Estimated_Max = Mx_o_Mx_Corr['Max Temp Estimation'].loc[0]
            Correlation_Max = Mx_o_Mx_Corr['Correlation Max T'].loc[0]
        else:
            Estimated_Max = Mx_o_Mx_Obs_Temp['Max Temp Estimation'].loc[0]
            Correlation_Max = Mx_o_Mx_Obs_Temp['Correlation Max T'].loc[0]
        
         #--------- MIN ------------#
        #Doing something more complicated
        #First lets find the max of the correlation for the max and min
    
        #nOW FOR TWO INDICES
        #First we choose the highest correlation as the initial condition
        Mx_o_Mn_Corr = data.loc[data['Correlation Min T'] == data['Correlation Min T'].max()]
        Mx_o_Mn_Corr = Mx_o_Mn_Corr.reset_index(drop = True)
    
        #Now we want to compare this Max temp Est to the max observed twmp of that day
        Mn_o_Mn_Obs_Temp = data.loc[data['temp'] == data['temp'].min()]
        Mn_o_Mn_Obs_Temp = Mn_o_Mn_Obs_Temp.reset_index(drop = True)
    
        #Check if Est is greater or equal to the Obs, this is to ensure that the highest correlation is kept
        if (Mx_o_Mn_Corr['Min Temp Estimation'].loc[0] <= Mn_o_Mn_Obs_Temp['temp'].loc[0]):
            Estimated_Min = Mx_o_Mn_Corr['Min Temp Estimation'].loc[0]
            Correlation_Min = Mx_o_Mn_Corr['Correlation Min T'].loc[0]
        else:
            Estimated_Min = Mn_o_Mn_Obs_Temp['Min Temp Estimation'].loc[0]
            Correlation_Min = Mn_o_Mn_Obs_Temp['Correlation Min T'].loc[0]
    
    else:
        #Doing something more complicated
    
        #------------------MAX-------------#
        #The first check is the highest correlation
    
    
        #First we choose the highest correlation as the initial condition
        Mx_o_Mx_Corr = data.loc[data['Correlation Max T'] == data['Correlation Max T'].max()]
        Mx_o_Mx_Corr = Mx_o_Mx_Corr.reset_index(drop = True)
    
        #Now we want to compare this Max temp Est to the max observed twmp of that day
        Mx_o_Mx_Obs_Temp = data.loc[data['temp'] == data['temp'].max()]
        Mx_o_Mx_Obs_Temp = Mx_o_Mx_Obs_Temp.reset_index(drop = True)
    
        #If proves that the highest correlation est is the highest value above any of the other obs temps
        #We can keep it if not
        if (Mx_o_Mx_Corr['Max Temp Estimation'].loc[0] >= Mx_o_Mx_Obs_Temp['temp'].loc[0]):
    
            Estimated_Max = Mx_o_Mx_Corr['Max Temp Estimation'].loc[0]
            Correlation_Max = Mx_o_Mx_Corr['Correlation Max T'].loc[0]
        
        
        else:
            #Now to see if the Est of the observed is the biggest estimation
            Mx_o_Mx_Est = data.loc[data['Max Temp Estimation'] == data['Max Temp Estimation'].max()]
            Mx_o_Mx_Est = Mx_o_Mx_Corr.reset_index(drop = True)
    
            #if it is keep this value as we know the max is the greatest that day
            if (Mx_o_Mx_Est['Max Temp Estimation'].loc[0] <= Mx_o_Mx_Obs_Temp['Max Temp Estimation'].loc[0]):
                Estimated_Max = Mx_o_Mx_Obs_Temp['Max Temp Estimation'].loc[0]
                Correlation_Max = Mx_o_Mx_Obs_Temp['Correlation Max T'].loc[0]
            
            else:
                #Now we need to check the correlation as the greater correlation will be the one to take hold, we want obs
                #To have the higher correlation first
                if (Mx_o_Mx_Obs_Temp['Correlation Max T'].loc[0] >= Mx_o_Mx_Est['Correlation Max T'].loc[0]):
                    Estimated_Max = Mx_o_Mx_Obs_Temp['Max Temp Estimation'].loc[0]
                    Correlation_Max = Mx_o_Mx_Obs_Temp['Correlation Max T'].loc[0]
                else:
                    Estimated_Max = Mx_o_Mx_Est['Max Temp Estimation'].loc[0]
                    Correlation_Max = Mx_o_Mx_Est['Correlation Max T'].loc[0]
    
         #------------------MIN-------------#
        #The first check is the highest correlation
    
    
        #First we choose the highest correlation as the initial condition
        Mx_o_Mn_Corr = data.loc[data['Correlation Min T'] == data['Correlation Min T'].max()]
        Mx_o_Mn_Corr = Mx_o_Mn_Corr.reset_index(drop = True)
    
        #Now we want to compare this Min temp Est to the min observed twmp of that day
        Mn_o_Mn_Obs_Temp = data.loc[data['temp'] == data['temp'].min()]
        Mn_o_Mn_Obs_Temp = Mn_o_Mn_Obs_Temp.reset_index(drop = True)
    
        #If proves that the highest correlation est is the highest value above any of the other obs temps
        #We can keep it if not
        if (Mx_o_Mn_Corr['Min Temp Estimation'].loc[0] <= Mn_o_Mn_Obs_Temp['temp'].loc[0]):
    
            Estimated_Min = Mx_o_Mn_Corr['Min Temp Estimation'].loc[0]
            Correlation_Min = Mx_o_Mn_Corr['Correlation Min T'].loc[0]
        
        
        else:
            #Now to see if the Est of the observed is the biggest estimation
            Mn_o_Mn_Est = data.loc[data['Min Temp Estimation'] == data['Min Temp Estimation'].min()]
            Mn_o_Mn_Est = Mx_o_Mn_Corr.reset_index(drop = True)
    
            #if it is keep this value as we know the max is the greatest that day
            if (Mn_o_Mn_Est['Min Temp Estimation'].loc[0] >= Mn_o_Mn_Obs_Temp['Min Temp Estimation'].loc[0]):
                Estimated_Min = Mn_o_Mn_Obs_Temp['Min Temp Estimation'].loc[0]
                Correlation_Min = Mn_o_Mn_Obs_Temp['Correlation Min T'].loc[0]
            
            else:
                #Now we need to check the correlation as the greater correlation will be the one to take hold, we want obs
                #To have the higher correlation first
                if (Mn_o_Mn_Obs_Temp['Correlation Min T'].loc[0] >= Mn_o_Mn_Est['Correlation Min T'].loc[0]):
                    Estimated_Min = Mn_o_Mn_Obs_Temp['Min Temp Estimation'].loc[0]
                    Correlation_Min = Mn_o_Mn_Obs_Temp['Correlation Min T'].loc[0]
                else:
                    Estimated_Min = Mn_o_Mn_Est['Min Temp Estimation'].loc[0]
                    Correlation_Min = Mn_o_Mn_Est['Correlation Min T'].loc[0]
    
    return(Estimated_Max,Estimated_Min,Correlation_Max,Correlation_Min)

# %%
#The final stage is to build the estimation checker etc
#What we have is
Uncut_Estimation_Dic = {}


for trialing in range(1,Trials):
    #All the saved information
    Estimated_Max = []
    Estimated_Min = []
    Max_T_Correlation = []
    Min_T_Correlation = []

    
    #Now lets go into the index of each individual vlaue
    for indexed in range(len(Per_Gard)):
        #Extract the particular day of focus
        Hist_Day = Per_Gard.loc[indexed]
        
        #Extract hour, month and temp
        Month_Extractor = Hist_Day['date'].month
        Hour = Hist_Day['Closest hour']
        Temp = Hist_Day['temp']
        
        #Estimation funcion
        Est_Max, Est_Min, Correlation_Max, Correlation_Min = estimation_ind_day_function(Month_Extractor, Hour,
                                                                                         Temp, All_data, trialing)
        Estimated_Max.append(Est_Max)
        Estimated_Min.append(Est_Min)
        Max_T_Correlation.append(Correlation_Max)
        Min_T_Correlation.append(Correlation_Min)
        
           
    #Add to the historical period
    Estimated_Max = pd.Series(Estimated_Max,name = 'Max Temp Estimation')
    Estimated_Min = pd.Series(Estimated_Min,name = 'Min Temp Estimation')
    Max_T_Correlation = pd.Series(Max_T_Correlation,name = 'Correlation Max T')
    Min_T_Correlation = pd.Series(Min_T_Correlation,name = 'Correlation Min T')
    Per_Gard_Estimation = pd.concat([Per_Gard, Estimated_Max,Estimated_Min,Max_T_Correlation,Min_T_Correlation],axis=1)

    #Add to a dictionary
    
    key_Hist = 'Trial'+ "_" + str(trialing)
    Uncut_Estimation_Dic[key_Hist] = Per_Gard_Estimation

# %%
#Now to choose the best one for the trials when there are 2 or more key temperatures
#Create_Dictionary
Estimated_Historical_Daily_Extremes = {}
#Start by going into individual trials
for ind_trial in range(1,Trials):
    #Extract the dictionary that is for the trial
    Sing_Hist_Est = Uncut_Estimation_Dic.get('Trial_{}'.format(ind_trial))
    
    #go through each day and get th best one for that day
    # Remove the duplicates out of the day it will make it easier for the for loop trust.

    # Remove the duplicates out of the day it will make it easier for the for loop trust.

    #Get the individual columns for the dates
    Sing_Hist_Est['Day'] = Sing_Hist_Est['date'].dt.day
    Sing_Hist_Est['Month'] = Sing_Hist_Est['date'].dt.month
    Sing_Hist_Est['Year'] = Sing_Hist_Est['date'].dt.year
    Estimation_Date = Sing_Hist_Est[['date','Year','Month','Day']]
    #Combine together as it removes hourly out of the datetime
    Estimation_Date['Undup Dates']=pd.to_datetime(Estimation_Date[['Year','Month','Day']])
    #Delete all other column remove dups reset index for looping, keep the undup dates and sub cats as well.
    Estimation_Date = Estimation_Date.drop_duplicates(subset=['Undup Dates'])
    del Estimation_Date['date']
    Estimation_Date = Estimation_Date.reset_index(drop = True)

    #The dataclean up is ready nn
    Sing_Hist_Est = Sing_Hist_Est.set_index('date')
    
    #Now we have to go through each individual day, check whether there is two or more values. So this is the first check
    Max_Estimated = []
    Max_CORR_Estimated = []
    Min_Estimated = []
    Min_CORR_Estimated = []
    Dates = []
    for i in range(len(Estimation_Date)):
        #Get the individual date
        located_date = Sing_Hist_Est.loc['{}-{}-{}'.format(Estimation_Date['Year'][i],Estimation_Date['Month'][i],Estimation_Date['Day'][i])]
        located_date = located_date.reset_index()
        #From here
        Estimated_Max,Estimated_Min,Correlation_Max,Correlation_Min =  estimation_single_date_temp_Complex(located_date)
        Max_Estimated.append(Estimated_Max)
        Max_CORR_Estimated.append(Correlation_Max)
        Min_Estimated.append(Estimated_Min)
        Min_CORR_Estimated.append(Correlation_Min)
         
    Max_Estimated = pd.Series(Max_Estimated,name = 'Max Temp Estimation')
    Min_Estimated = pd.Series(Min_Estimated,name = 'Min Temp Estimation')
    Max_CORR_Estimated = pd.Series(Max_CORR_Estimated,name = 'Correlation Max T')
    Min_CORR_Estimated = pd.Series(Min_CORR_Estimated,name = 'Correlation Min T')
    Estimated_Temp = pd.concat([Estimation_Date['Undup Dates'], Max_Estimated,Min_Estimated,Max_CORR_Estimated,Min_CORR_Estimated],axis=1)
    Estimated_Temp = Estimated_Temp.rename(columns={'Undup Dates':'Date'})
    #Add to a dictionary
    
    key_Hist_Proper = 'Trial'+ "_" + str(ind_trial)
    Estimated_Historical_Daily_Extremes[key_Hist_Proper] = Estimated_Temp
# Out:
# C:\Users\jarra\AppData\Local\Temp\ipykernel_3188\483243950.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Estimation_Date['Undup Dates']=pd.to_datetime(Estimation_Date[['Year','Month','Day']])

# %%
Estimated_Historical_Daily_Extremes.get('Trial_1')
# Out:
#             Date  Max Temp Estimation  Min Temp Estimation  Correlation Max T  \
# 0     1830-04-16            26.748880            15.385410           0.941589
# 1     1830-04-17            27.343486            18.055214           0.941589
# 2     1830-04-18            30.728399            18.966153           0.695674
# 3     1830-04-19            28.198141            16.564587           0.851682
# 4     1830-04-20            25.987303            12.755205           0.957487
# ...          ...                  ...                  ...                ...
# 13800 1875-12-24            26.438312            18.629618           0.975518
# 13801 1875-12-28            38.460379            19.484729           0.975518
# 13802 1875-12-29            35.583303            18.629618           0.975518
# 13803 1875-12-30            32.706227            19.507428           0.975518
# 13804 1875-12-31            27.054829            19.068523           0.975518
#
#        Correlation Min T
# 0               0.528846
# 1               0.814510
# 2               0.814510
# 3               0.814510
# 4               0.814510
# ...                  ...
# 13800           0.806169
# 13801           0.461723
# 13802           0.806169
# 13803           0.806169
# 13804           0.806169
#
# [13805 rows x 5 columns]

# %%
def estimation_single_date_temp_Simple(data):
  
    #Single Case: Most simple
    if (len(data) == 1):
        #This finds the values required for a length of 1 data
        Estimated_Max = data['Max Temp Estimation'].loc[0]
        Estimated_Min = data['Min Temp Estimation'].loc[0]
        Correlation_Max = data['Correlation Max T'].loc[0]
        Correlation_Min = data['Correlation Min T'].loc[0]


    else:
        #--------- MAX ------------#
        #Doing something more complicated
        #First lets find the max of the correlation for the max and min
    
        #nOW FOR TWO INDICES
        #First we choose the highest correlation as the initial condition
        Mx_o_Mx_Corr = data.loc[data['Correlation Max T'] == data['Correlation Max T'].max()]
        Mx_o_Mx_Corr = Mx_o_Mx_Corr.reset_index(drop = True)
        Estimated_Max = Mx_o_Mx_Corr['Max Temp Estimation'].loc[0]
        Correlation_Max = Mx_o_Mx_Corr['Correlation Max T'].loc[0]
    
    
         #--------- MIN ------------#
        #Doing something more complicated
        #First lets find the max of the correlation for the max and min
    
        #nOW FOR TWO INDICES
        #First we choose the highest correlation as the initial condition
        Mx_o_Mn_Corr = data.loc[data['Correlation Min T'] == data['Correlation Min T'].max()]
        Mx_o_Mn_Corr = Mx_o_Mn_Corr.reset_index(drop = True)
    
   
        Estimated_Min = Mx_o_Mn_Corr['Min Temp Estimation'].loc[0]
        Correlation_Min = Mx_o_Mn_Corr['Correlation Min T'].loc[0]
        
        
    return(Estimated_Max,Estimated_Min,Correlation_Max,Correlation_Min)

# %%
A_Simp = Estimated_Historical_Daily_Extremes.get('Trial_1')
#A.resample('Y').mean()
A_Simp = A_Simp.set_index('Date')

# %%
A = Estimated_Historical_Daily_Extremes.get('Trial_1')
#A.resample('Y').mean()
A = A.set_index('Date')

# %%
A.resample('Y').mean().plot()
A_Simp.resample('Y').mean().plot()
PRO_DE.resample('Y').mean().plot()
A_Simp.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
A2 = A_Simp.loc['1831-01-01':'1831-12-31']
A2.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
len(A_Simp[A_Simp['Max Temp Estimation']<20])/len(A_Simp)
# Out:
# 0.2933719666787396

# %%
len(PRO_DE[PRO_DE['PRO Max']<20])/len(PRO_DE)
# Out:
# 0.34681333831174427

# %%
PRO_DE
P = PRO_DE.loc['1897-01-01':'1897-12-31']
P.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# 1. Overepresentation of 40+ days
# 2. There are a few 50+ days in the historical record - NOT good
# 3. Varibility of the temperatures do match the PRO_DE for 1 year
# 4. The means overepresentated by about 2.5C
# 5. Is that because of the location it was as well and missing data why mean is overrepresented

# %%
# Out:
#             Max Temp Estimation  Min Temp Estimation  Correlation Max T  \
# Date
# 1830-04-16            24.823275            15.385410           0.957487
# 1830-04-17            27.343486            18.055214           0.941589
# 1830-04-18            30.728399            18.966153           0.695674
# 1830-04-19            28.198141            16.564587           0.851682
# 1830-04-20            25.987303            12.755205           0.957487
# ...                         ...                  ...                ...
# 1875-12-24            26.438312            18.629618           0.975518
# 1875-12-28            38.460379            19.484729           0.975518
# 1875-12-29            35.583303            18.629618           0.975518
# 1875-12-30            32.706227            19.507428           0.975518
# 1875-12-31            27.054829            19.068523           0.975518
#
#             Correlation Min T
# Date
# 1830-04-16           0.528846
# 1830-04-17           0.814510
# 1830-04-18           0.814510
# 1830-04-19           0.814510
# 1830-04-20           0.814510
# ...                       ...
# 1875-12-24           0.806169
# 1875-12-28           0.461723
# 1875-12-29           0.806169
# 1875-12-30           0.806169
# 1875-12-31           0.806169
#
# [13805 rows x 4 columns]

# %%
Per_Gard.set_index('date').loc['1830-12-17']
# Out:
#                      temp  Closest hour
# date
# 1830-12-17 09:00:00  36.9             9
# 1830-12-17 12:00:00  48.9            12
# 1830-12-17 15:00:00  33.6            15

# %%
Per_Gard.set_index('date').loc['1863-01-01']
# Out:
#                      temp  Closest hour
# date
# 1863-01-01 12:00:00  49.8            12
# 1863-01-01 16:00:00  35.6            15

# %%
Involve blair more

start looking at 20cr

Start off bigger for the 20cr so Indian Ocean to NZ 
Looking at what are the conditions so look at heatwave days

Start looking at surface variables MLSP and temp, SST
